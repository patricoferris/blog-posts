# %% [markdown]
# ### Webscraping
# ------------------------

# %%
import requests
from bs4 import BeautifulSoup
import json

result = requests.get('https://github.com/factbook/factbook.json')

content = result.content

bsoup = BeautifulSoup(content, 'html5lib')

tds = bsoup.find_all('td', class_='content')

continents = []
for td in tds[1:14]:
    continents.append(td.text.split('\n')[1].split(' ')[-1])

code_to_continent = {}

for continent in continents: 
    if continent != 'meta':
        url = 'https://github.com/factbook/factbook.json/tree/master/{c}'.format(c=continent)
        countries_page = requests.get(url)
        content = countries_page.content
        bsoup = BeautifulSoup(content, 'html5lib')
        tds = bsoup.find_all('td', class_='content')
        for td in tds[1:]:
            code_to_continent[td.text.split('\n')[1].split(' ')[-1].split('.')[0]] = continent

# %%
class Country:
    def __init__(self, name, code):
        self.name = name.lower()
        self.code = code
        self.exporting_partners = {}
    def add_partner(self, p, v):
        self.exporting_partners[p] = v

# %%
idx = 0

countries = {}

for code in code_to_continent:
    print(code)
    url = 'https://raw.githubusercontent.com/factbook/factbook.json/master/{continent}/{code}.json'.format(continent=code_to_continent[code], code=code)
    print(url)
    json = requests.get(url).json()
    if 'Country name' in json['Government']:
        if 'conventional short form' in json['Government']['Country name']:
            name = json['Government']['Country name']['conventional short form']['text']
            if 'Exports - partners' in json['Economy']:
                partners = json['Economy']['Exports - partners']['text'].split(',')
                #print(partners)
                country = Country(name, code)
                for partner in partners:
                    p = partner.split()
                    if p[-1][0] == '(':
                        country.add_partner(' '.join(p[0:-2]).lower(), float(p[-2].split('%')[0]))
                    elif p[-1][0] == 'e':
                        country.add_partner(' '.join(p[0:-3]).lower(), float(p[-3].split('%')[0]))  
                        #print(p)
                    else:
                        country.add_partner(' '.join(p[0:-1]).lower(), float(p[-1].split('%')[0]))
                countries[code] = country
# Out:
# ag
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ag.json
# ao
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ao.json
# bc
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/bc.json
# bn
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/bn.json
# by
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/by.json
# cd
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/cd.json
# cf
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/cf.json
# cg
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/cg.json
# cm
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/cm.json
# cn
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/cn.json
# ct
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ct.json
# cv
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/cv.json
# dj
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/dj.json
# eg
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/eg.json
# ek
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ek.json
# er
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/er.json
# et
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/et.json
# ga
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ga.json
# gb
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/gb.json
# gh
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/gh.json
# gv
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/gv.json
# iv
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/iv.json
# ke
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ke.json
# li
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/li.json
# lt
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/lt.json
# ly
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ly.json
# ma
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ma.json
# mi
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/mi.json
# ml
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ml.json
# mo
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/mo.json
# mp
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/mp.json
# mr
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/mr.json
# mz
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/mz.json
# ng
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ng.json
# ni
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ni.json
# od
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/od.json
# pu
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/pu.json
# rw
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/rw.json
# se
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/se.json
# sf
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/sf.json
# sg
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/sg.json
# sh
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/sh.json
# sl
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/sl.json
# so
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/so.json
# su
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/su.json
# to
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/to.json
# tp
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/tp.json
# ts
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ts.json
# tz
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/tz.json
# ug
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ug.json
# uv
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/uv.json
# wa
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/wa.json
# wi
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/wi.json
# wz
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/wz.json
# za
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/za.json
# zi
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/zi.json
# ay
# https://raw.githubusercontent.com/factbook/factbook.json/master/antarctica/ay.json
# bv
# https://raw.githubusercontent.com/factbook/factbook.json/master/antarctica/bv.json
# fs
# https://raw.githubusercontent.com/factbook/factbook.json/master/antarctica/fs.json
# hm
# https://raw.githubusercontent.com/factbook/factbook.json/master/antarctica/hm.json
# aq
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/aq.json
# as
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/as.json
# at
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/at.json
# bp
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/bp.json
# ck
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/ck.json
# cq
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/cq.json
# cr
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/cr.json
# cw
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/cw.json
# fj
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/fj.json
# fm
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/fm.json
# fp
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/fp.json
# gq
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/gq.json
# kr
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/kr.json
# kt
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/kt.json
# nc
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/nc.json
# ne
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/ne.json
# nf
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/nf.json
# nh
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/nh.json
# nr
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/nr.json
# nz
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/nz.json
# pc
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/pc.json
# ps
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/ps.json
# rm
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/rm.json
# tl
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/tl.json
# tn
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/tn.json
# tv
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/tv.json
# um
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/um.json
# wf
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/wf.json
# wq
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/wq.json
# ws
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/ws.json
# aa
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/aa.json
# ac
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/ac.json
# av
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/av.json
# bb
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/bb.json
# bf
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/bf.json
# bh
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/bh.json
# bq
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/bq.json
# cc
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/cc.json
# cj
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/cj.json
# cs
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/cs.json
# cu
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/cu.json
# do
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/do.json
# dr
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/dr.json
# es
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/es.json
# gj
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/gj.json
# gt
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/gt.json
# ha
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/ha.json
# ho
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/ho.json
# jm
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/jm.json
# mh
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/mh.json
# nu
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/nu.json
# pm
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/pm.json
# rn
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/rn.json
# rq
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/rq.json
# sc
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/sc.json
# sk
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/sk.json
# st
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/st.json
# tb
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/tb.json
# td
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/td.json
# tk
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/tk.json
# vc
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/vc.json
# vi
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/vi.json
# vq
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/vq.json
# kg
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-asia/kg.json
# kz
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-asia/kz.json
# rs
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-asia/rs.json
# ti
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-asia/ti.json
# tx
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-asia/tx.json
# uz
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-asia/uz.json
# bm
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/bm.json
# bx
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/bx.json
# cb
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/cb.json
# ch
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/ch.json
# hk
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/hk.json
# id
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/id.json
# ja
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/ja.json
# kn
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/kn.json
# ks
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/ks.json
# la
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/la.json
# mc
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/mc.json
# mg
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/mg.json
# my
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/my.json
# pf
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/pf.json
# pg
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/pg.json
# pp
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/pp.json
# rp
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/rp.json
# sn
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/sn.json
# th
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/th.json
# tt
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/tt.json
# tw
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/tw.json
# vm
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/vm.json
# al
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/al.json
# an
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/an.json
# au
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/au.json
# ax
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ax.json
# be
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/be.json
# bk
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/bk.json
# bo
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/bo.json
# bu
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/bu.json
# cy
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/cy.json
# da
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/da.json
# dx
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/dx.json
# ee
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ee.json
# ei
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ei.json
# en
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/en.json
# ez
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ez.json
# fi
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/fi.json
# fo
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/fo.json
# fr
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/fr.json
# gi
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/gi.json
# gk
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/gk.json
# gm
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/gm.json
# gr
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/gr.json
# hr
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/hr.json
# hu
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/hu.json
# ic
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ic.json
# im
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/im.json
# it
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/it.json
# je
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/je.json
# jn
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/jn.json
# kv
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/kv.json
# lg
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/lg.json
# lh
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/lh.json
# lo
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/lo.json
# ls
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ls.json
# lu
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/lu.json
# md
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/md.json
# mj
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/mj.json
# mk
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/mk.json
# mn
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/mn.json
# mt
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/mt.json
# nl
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/nl.json
# no
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/no.json
# pl
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/pl.json
# po
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/po.json
# ri
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ri.json
# ro
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ro.json
# si
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/si.json
# sm
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/sm.json
# sp
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/sp.json
# sv
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/sv.json
# sw
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/sw.json
# sz
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/sz.json
# uk
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/uk.json
# up
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/up.json
# vt
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/vt.json
# ae
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/ae.json
# aj
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/aj.json
# am
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/am.json
# ba
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/ba.json
# gg
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/gg.json
# gz
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/gz.json
# ir
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/ir.json
# is
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/is.json
# iz
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/iz.json
# jo
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/jo.json
# ku
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/ku.json
# le
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/le.json
# mu
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/mu.json
# qa
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/qa.json
# sa
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/sa.json
# sy
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/sy.json
# tu
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/tu.json
# we
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/we.json
# ym
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/ym.json
# bd
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/bd.json
# ca
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/ca.json
# gl
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/gl.json
# ip
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/ip.json
# mx
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/mx.json
# sb
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/sb.json
# us
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/us.json
# oo
# https://raw.githubusercontent.com/factbook/factbook.json/master/oceans/oo.json
# xo
# https://raw.githubusercontent.com/factbook/factbook.json/master/oceans/xo.json
# xq
# https://raw.githubusercontent.com/factbook/factbook.json/master/oceans/xq.json
# zh
# https://raw.githubusercontent.com/factbook/factbook.json/master/oceans/zh.json
# zn
# https://raw.githubusercontent.com/factbook/factbook.json/master/oceans/zn.json
# ar
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/ar.json
# bl
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/bl.json
# br
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/br.json
# ci
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/ci.json
# co
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/co.json
# ec
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/ec.json
# fk
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/fk.json
# gy
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/gy.json
# ns
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/ns.json
# pa
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/pa.json
# pe
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/pe.json
# sx
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/sx.json
# uy
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/uy.json
# ve
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/ve.json
# af
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/af.json
# bg
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/bg.json
# bt
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/bt.json
# ce
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/ce.json
# in
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/in.json
# io
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/io.json
# mv
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/mv.json
# np
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/np.json
# pk
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/pk.json

# %%
import pandas as pd
import networkx as nx
import matplotlib as plt
G = nx.DiGraph()

for country in countries:
    for partner in countries[country].exporting_partners: 
        G.add_edge(countries[country].name, partner, weight=countries[country].exporting_partners[partner]/100)

# %%
degrees = nx.degree(G)

ds = {}
for name, d in degrees: 
    ds[name] = d

nx.set_node_attributes(G, ds, 'degree')

# %%
from networkx.readwrite import json_graph
data = json_graph.node_link_data(G)

# %%
import json
with open('graph.json', 'w') as fp:
    json.dump(data, fp)

# %%
data
# Out:
# {'directed': True,
#  'graph': {},
#  'links': [{'source': 'algeria', 'target': 'spain', 'weight': 0.188},
#   {'source': 'algeria', 'target': 'france', 'weight': 0.11199999999999999},
#   {'source': 'algeria', 'target': 'us', 'weight': 0.08800000000000001},
#   {'source': 'algeria', 'target': 'italy', 'weight': 0.087},
#   {'source': 'algeria', 'target': 'uk', 'weight': 0.071},
#   {'source': 'algeria', 'target': 'brazil', 'weight': 0.052000000000000005},
#   {'source': 'algeria', 'target': 'tunisia', 'weight': 0.049},
#   {'source': 'algeria', 'target': 'germany', 'weight': 0.045},
#   {'source': 'spain', 'target': 'france', 'weight': 0.157},
#   {'source': 'spain', 'target': 'germany', 'weight': 0.11},
#   {'source': 'spain', 'target': 'italy', 'weight': 0.07400000000000001},
#   {'source': 'spain', 'target': 'uk', 'weight': 0.07400000000000001},
#   {'source': 'spain', 'target': 'portugal', 'weight': 0.071},
#   {'source': 'spain', 'target': 'us', 'weight': 0.045},
#   {'source': 'france', 'target': 'germany', 'weight': 0.159},
#   {'source': 'france', 'target': 'spain', 'weight': 0.073},
#   {'source': 'france', 'target': 'us', 'weight': 0.07200000000000001},
#   {'source': 'france', 'target': 'italy', 'weight': 0.071},
#   {'source': 'france', 'target': 'uk', 'weight': 0.071},
#   {'source': 'france', 'target': 'belgium', 'weight': 0.068},
#   {'source': 'italy', 'target': 'germany', 'weight': 0.12300000000000001},
#   {'source': 'italy', 'target': 'france', 'weight': 0.10300000000000001},
#   {'source': 'italy', 'target': 'us', 'weight': 0.087},
#   {'source': 'italy', 'target': 'uk', 'weight': 0.054000000000000006},
#   {'source': 'italy', 'target': 'spain', 'weight': 0.048},
#   {'source': 'italy', 'target': 'switzerland', 'weight': 0.047},
#   {'source': 'brazil', 'target': 'china', 'weight': 0.18600000000000003},
#   {'source': 'brazil', 'target': 'us', 'weight': 0.127},
#   {'source': 'brazil', 'target': 'argentina', 'weight': 0.067},
#   {'source': 'brazil', 'target': 'netherlands', 'weight': 0.053},
#   {'source': 'tunisia', 'target': 'france', 'weight': 0.285},
#   {'source': 'tunisia', 'target': 'italy', 'weight': 0.172},
#   {'source': 'tunisia', 'target': 'germany', 'weight': 0.109},
#   {'source': 'tunisia', 'target': 'libya', 'weight': 0.061},
#   {'source': 'tunisia', 'target': 'spain', 'weight': 0.042},
#   {'source': 'germany', 'target': 'us', 'weight': 0.096},
#   {'source': 'germany', 'target': 'france', 'weight': 0.086},
#   {'source': 'germany', 'target': 'uk', 'weight': 0.075},
#   {'source': 'germany', 'target': 'netherlands', 'weight': 0.066},
#   {'source': 'germany', 'target': 'china', 'weight': 0.06},
#   {'source': 'germany', 'target': 'italy', 'weight': 0.049},
#   {'source': 'germany', 'target': 'austria', 'weight': 0.048},
#   {'source': 'germany', 'target': 'poland', 'weight': 0.044000000000000004},
#   {'source': 'germany', 'target': 'switzerland', 'weight': 0.042},
#   {'source': 'angola', 'target': 'china', 'weight': 0.43799999999999994},
#   {'source': 'angola', 'target': 'india', 'weight': 0.096},
#   {'source': 'angola', 'target': 'us', 'weight': 0.077},
#   {'source': 'angola', 'target': 'spain', 'weight': 0.062},
#   {'source': 'angola', 'target': 'south africa', 'weight': 0.048},
#   {'source': 'angola', 'target': 'france', 'weight': 0.044000000000000004},
#   {'source': 'china', 'target': 'us', 'weight': 0.18},
#   {'source': 'china', 'target': 'hong kong', 'weight': 0.146},
#   {'source': 'china', 'target': 'japan', 'weight': 0.06},
#   {'source': 'china', 'target': 'south korea', 'weight': 0.045},
#   {'source': 'india', 'target': 'us', 'weight': 0.152},
#   {'source': 'india', 'target': 'uae', 'weight': 0.114},
#   {'source': 'india', 'target': 'hong kong', 'weight': 0.046},
#   {'source': 'south africa', 'target': 'china', 'weight': 0.113},
#   {'source': 'south africa', 'target': 'us', 'weight': 0.073},
#   {'source': 'south africa', 'target': 'germany', 'weight': 0.06},
#   {'source': 'south africa',
#    'target': 'namibia',
#    'weight': 0.052000000000000005},
#   {'source': 'south africa',
#    'target': 'botswana',
#    'weight': 0.052000000000000005},
#   {'source': 'south africa', 'target': 'japan', 'weight': 0.047},
#   {'source': 'south africa', 'target': 'uk', 'weight': 0.043},
#   {'source': 'south africa', 'target': 'india', 'weight': 0.042},
#   {'source': 'benin', 'target': 'india', 'weight': 0.242},
#   {'source': 'benin', 'target': 'gabon', 'weight': 0.146},
#   {'source': 'benin', 'target': 'china', 'weight': 0.07200000000000001},
#   {'source': 'benin', 'target': 'niger', 'weight': 0.06},
#   {'source': 'benin', 'target': 'bangladesh', 'weight': 0.05},
#   {'source': 'benin', 'target': 'nigeria', 'weight': 0.049},
#   {'source': 'benin', 'target': 'vietnam', 'weight': 0.042},
#   {'source': 'gabon', 'target': 'china', 'weight': 0.155},
#   {'source': 'gabon', 'target': 'italy', 'weight': 0.073},
#   {'source': 'gabon',
#    'target': 'trinidad and tobago',
#    'weight': 0.07200000000000001},
#   {'source': 'gabon', 'target': 'australia', 'weight': 0.07},
#   {'source': 'gabon', 'target': 'spain', 'weight': 0.063},
#   {'source': 'gabon', 'target': 'south korea', 'weight': 0.054000000000000006},
#   {'source': 'gabon', 'target': 'netherlands', 'weight': 0.05},
#   {'source': 'gabon', 'target': 'us', 'weight': 0.047},
#   {'source': 'niger', 'target': 'france', 'weight': 0.531},
#   {'source': 'niger', 'target': 'nigeria', 'weight': 0.203},
#   {'source': 'niger', 'target': 'china', 'weight': 0.138},
#   {'source': 'bangladesh', 'target': 'us', 'weight': 0.139},
#   {'source': 'bangladesh', 'target': 'germany', 'weight': 0.129},
#   {'source': 'bangladesh', 'target': 'uk', 'weight': 0.08900000000000001},
#   {'source': 'bangladesh', 'target': 'france', 'weight': 0.05},
#   {'source': 'bangladesh', 'target': 'spain', 'weight': 0.047},
#   {'source': 'nigeria', 'target': 'india', 'weight': 0.182},
#   {'source': 'nigeria', 'target': 'netherlands', 'weight': 0.085},
#   {'source': 'nigeria', 'target': 'spain', 'weight': 0.08199999999999999},
#   {'source': 'nigeria', 'target': 'brazil', 'weight': 0.08199999999999999},
#   {'source': 'nigeria', 'target': 'south africa', 'weight': 0.078},
#   {'source': 'nigeria', 'target': 'france', 'weight': 0.052000000000000005},
#   {'source': 'nigeria', 'target': 'japan', 'weight': 0.045},
#   {'source': 'nigeria', 'target': 'cote divoire', 'weight': 0.042},
#   {'source': 'nigeria', 'target': 'ghana', 'weight': 0.04},
#   {'source': 'vietnam', 'target': 'us', 'weight': 0.212},
#   {'source': 'vietnam', 'target': 'china', 'weight': 0.133},
#   {'source': 'vietnam', 'target': 'japan', 'weight': 0.084},
#   {'source': 'vietnam', 'target': 'south korea', 'weight': 0.055},
#   {'source': 'vietnam', 'target': 'germany', 'weight': 0.040999999999999995},
#   {'source': 'burundi', 'target': 'germany', 'weight': 0.12300000000000001},
#   {'source': 'burundi', 'target': 'pakistan', 'weight': 0.107},
#   {'source': 'burundi',
#    'target': 'democratic republic of the congo',
#    'weight': 0.107},
#   {'source': 'burundi', 'target': 'uganda', 'weight': 0.081},
#   {'source': 'burundi', 'target': 'sweden', 'weight': 0.078},
#   {'source': 'burundi', 'target': 'us', 'weight': 0.071},
#   {'source': 'burundi', 'target': 'belgium', 'weight': 0.063},
#   {'source': 'burundi', 'target': 'rwanda', 'weight': 0.046},
#   {'source': 'burundi', 'target': 'france', 'weight': 0.044000000000000004},
#   {'source': 'pakistan', 'target': 'us', 'weight': 0.131},
#   {'source': 'pakistan', 'target': 'uae', 'weight': 0.091},
#   {'source': 'pakistan', 'target': 'afghanistan', 'weight': 0.091},
#   {'source': 'pakistan', 'target': 'china', 'weight': 0.08800000000000001},
#   {'source': 'pakistan', 'target': 'uk', 'weight': 0.054000000000000006},
#   {'source': 'pakistan', 'target': 'germany', 'weight': 0.049},
#   {'source': 'uganda', 'target': 'rwanda', 'weight': 0.107},
#   {'source': 'uganda', 'target': 'uae', 'weight': 0.099},
#   {'source': 'uganda',
#    'target': 'democratic republic of the congo',
#    'weight': 0.098},
#   {'source': 'uganda', 'target': 'kenya', 'weight': 0.09699999999999999},
#   {'source': 'uganda', 'target': 'italy', 'weight': 0.057999999999999996},
#   {'source': 'uganda', 'target': 'netherlands', 'weight': 0.048},
#   {'source': 'uganda', 'target': 'germany', 'weight': 0.047},
#   {'source': 'uganda', 'target': 'china', 'weight': 0.040999999999999995},
#   {'source': 'sweden', 'target': 'norway', 'weight': 0.10300000000000001},
#   {'source': 'sweden', 'target': 'germany', 'weight': 0.10300000000000001},
#   {'source': 'sweden', 'target': 'us', 'weight': 0.077},
#   {'source': 'sweden', 'target': 'uk', 'weight': 0.07200000000000001},
#   {'source': 'sweden', 'target': 'denmark', 'weight': 0.068},
#   {'source': 'sweden', 'target': 'finland', 'weight': 0.067},
#   {'source': 'sweden',
#    'target': 'netherlands',
#    'weight': 0.052000000000000005},
#   {'source': 'sweden', 'target': 'belgium', 'weight': 0.044000000000000004},
#   {'source': 'sweden', 'target': 'france', 'weight': 0.042},
#   {'source': 'belgium', 'target': 'germany', 'weight': 0.16899999999999998},
#   {'source': 'belgium', 'target': 'france', 'weight': 0.155},
#   {'source': 'belgium', 'target': 'netherlands', 'weight': 0.114},
#   {'source': 'belgium', 'target': 'uk', 'weight': 0.08800000000000001},
#   {'source': 'belgium', 'target': 'us', 'weight': 0.06},
#   {'source': 'belgium', 'target': 'italy', 'weight': 0.05},
#   {'source': 'rwanda',
#    'target': 'democratic republic of the congo',
#    'weight': 0.198},
#   {'source': 'rwanda', 'target': 'us', 'weight': 0.10800000000000001},
#   {'source': 'rwanda', 'target': 'china', 'weight': 0.10300000000000001},
#   {'source': 'rwanda', 'target': 'swaziland', 'weight': 0.079},
#   {'source': 'rwanda', 'target': 'malaysia', 'weight': 0.07},
#   {'source': 'rwanda', 'target': 'pakistan', 'weight': 0.062},
#   {'source': 'rwanda', 'target': 'germany', 'weight': 0.059000000000000004},
#   {'source': 'rwanda', 'target': 'thailand', 'weight': 0.055},
#   {'source': 'chad', 'target': 'us', 'weight': 0.585},
#   {'source': 'chad', 'target': 'india', 'weight': 0.133},
#   {'source': 'chad', 'target': 'japan', 'weight': 0.113},
#   {'source': 'chad', 'target': 'china', 'weight': 0.040999999999999995},
#   {'source': 'japan', 'target': 'us', 'weight': 0.20199999999999999},
#   {'source': 'japan', 'target': 'china', 'weight': 0.175},
#   {'source': 'japan', 'target': 'south korea', 'weight': 0.071},
#   {'source': 'japan', 'target': 'hong kong', 'weight': 0.055999999999999994},
#   {'source': 'japan', 'target': 'thailand', 'weight': 0.045},
#   {'source': 'congo (brazzaville)',
#    'target': 'china',
#    'weight': 0.42100000000000004},
#   {'source': 'congo (brazzaville)',
#    'target': 'italy',
#    'weight': 0.16899999999999998},
#   {'source': 'congo (brazzaville)', 'target': 'us', 'weight': 0.049},
#   {'source': 'congo (brazzaville)', 'target': 'india', 'weight': 0.047},
#   {'source': 'congo (brazzaville)', 'target': 'portugal', 'weight': 0.042},
#   {'source': 'portugal', 'target': 'spain', 'weight': 0.25},
#   {'source': 'portugal', 'target': 'france', 'weight': 0.121},
#   {'source': 'portugal', 'target': 'germany', 'weight': 0.11800000000000001},
#   {'source': 'portugal', 'target': 'uk', 'weight': 0.067},
#   {'source': 'portugal', 'target': 'us', 'weight': 0.052000000000000005},
#   {'source': 'portugal', 'target': 'angola', 'weight': 0.042},
#   {'source': 'portugal', 'target': 'netherlands', 'weight': 0.04},
#   {'source': 'drc', 'target': 'china', 'weight': 0.435},
#   {'source': 'drc', 'target': 'zambia', 'weight': 0.25},
#   {'source': 'drc', 'target': 'south korea', 'weight': 0.049},
#   {'source': 'drc', 'target': 'belgium', 'weight': 0.048},
#   {'source': 'zambia', 'target': 'china', 'weight': 0.255},
#   {'source': 'zambia',
#    'target': 'democratic republic of the congo',
#    'weight': 0.13},
#   {'source': 'zambia', 'target': 'south africa', 'weight': 0.064},
#   {'source': 'zambia', 'target': 'south korea', 'weight': 0.049},
#   {'source': 'zambia', 'target': 'india', 'weight': 0.043},
#   {'source': 'south korea', 'target': 'china', 'weight': 0.26},
#   {'source': 'south korea', 'target': 'us', 'weight': 0.133},
#   {'source': 'south korea',
#    'target': 'hong kong',
#    'weight': 0.057999999999999996},
#   {'source': 'south korea', 'target': 'vietnam', 'weight': 0.053},
#   {'source': 'south korea', 'target': 'japan', 'weight': 0.049},
#   {'source': 'cameroon', 'target': 'china', 'weight': 0.16699999999999998},
#   {'source': 'cameroon', 'target': 'india', 'weight': 0.157},
#   {'source': 'cameroon', 'target': 'spain', 'weight': 0.062},
#   {'source': 'cameroon', 'target': 'belgium', 'weight': 0.061},
#   {'source': 'cameroon', 'target': 'france', 'weight': 0.061},
#   {'source': 'cameroon', 'target': 'portugal', 'weight': 0.055999999999999994},
#   {'source': 'cameroon', 'target': 'netherlands', 'weight': 0.05},
#   {'source': 'cameroon', 'target': 'italy', 'weight': 0.05},
#   {'source': 'netherlands', 'target': 'germany', 'weight': 0.245},
#   {'source': 'netherlands', 'target': 'belgium', 'weight': 0.111},
#   {'source': 'netherlands', 'target': 'uk', 'weight': 0.09300000000000001},
#   {'source': 'netherlands', 'target': 'france', 'weight': 0.084},
#   {'source': 'netherlands', 'target': 'italy', 'weight': 0.042},
#   {'source': 'comoros', 'target': 'india', 'weight': 0.287},
#   {'source': 'comoros', 'target': 'france', 'weight': 0.17},
#   {'source': 'comoros', 'target': 'germany', 'weight': 0.087},
#   {'source': 'comoros', 'target': 'saudi arabia', 'weight': 0.071},
#   {'source': 'comoros', 'target': 'singapore', 'weight': 0.066},
#   {'source': 'comoros', 'target': 'netherlands', 'weight': 0.061},
#   {'source': 'comoros', 'target': 'mauritius', 'weight': 0.053},
#   {'source': 'saudi arabia', 'target': 'china', 'weight': 0.132},
#   {'source': 'saudi arabia', 'target': 'japan', 'weight': 0.109},
#   {'source': 'saudi arabia', 'target': 'us', 'weight': 0.096},
#   {'source': 'saudi arabia', 'target': 'india', 'weight': 0.096},
#   {'source': 'saudi arabia', 'target': 'south korea', 'weight': 0.085},
#   {'source': 'singapore', 'target': 'china', 'weight': 0.13699999999999998},
#   {'source': 'singapore', 'target': 'hong kong', 'weight': 0.115},
#   {'source': 'singapore', 'target': 'malaysia', 'weight': 0.10800000000000001},
#   {'source': 'singapore',
#    'target': 'indonesia',
#    'weight': 0.08199999999999999},
#   {'source': 'singapore', 'target': 'us', 'weight': 0.069},
#   {'source': 'singapore', 'target': 'japan', 'weight': 0.044000000000000004},
#   {'source': 'singapore',
#    'target': 'south korea',
#    'weight': 0.040999999999999995},
#   {'source': 'mauritius', 'target': 'uk', 'weight': 0.132},
#   {'source': 'mauritius', 'target': 'uae', 'weight': 0.124},
#   {'source': 'mauritius', 'target': 'france', 'weight': 0.11900000000000001},
#   {'source': 'mauritius', 'target': 'us', 'weight': 0.107},
#   {'source': 'mauritius', 'target': 'south africa', 'weight': 0.086},
#   {'source': 'mauritius', 'target': 'madagascar', 'weight': 0.065},
#   {'source': 'mauritius', 'target': 'italy', 'weight': 0.054000000000000006},
#   {'source': 'mauritius', 'target': 'spain', 'weight': 0.044000000000000004},
#   {'source': 'none', 'target': 'norway', 'weight': 0.522},
#   {'source': 'none', 'target': 'china', 'weight': 0.047},
#   {'source': 'none',
#    'target': 'democratic republic of the congo',
#    'weight': 0.083},
#   {'source': 'none', 'target': 'iran', 'weight': 0.145},
#   {'source': 'none', 'target': 'japan', 'weight': 0.098},
#   {'source': 'none', 'target': 'india', 'weight': 0.092},
#   {'source': 'none', 'target': 'oman', 'weight': 0.043},
#   {'source': 'norway', 'target': 'uk', 'weight': 0.222},
#   {'source': 'norway', 'target': 'germany', 'weight': 0.179},
#   {'source': 'norway', 'target': 'netherlands', 'weight': 0.102},
#   {'source': 'norway', 'target': 'france', 'weight': 0.066},
#   {'source': 'norway', 'target': 'sweden', 'weight': 0.061},
#   {'source': 'norway', 'target': 'belgium', 'weight': 0.05},
#   {'source': 'norway', 'target': 'us', 'weight': 0.045},
#   {'source': 'cabo verde', 'target': 'australia', 'weight': 0.83},
#   {'source': 'cabo verde', 'target': 'spain', 'weight': 0.086},
#   {'source': 'australia', 'target': 'china', 'weight': 0.322},
#   {'source': 'australia', 'target': 'japan', 'weight': 0.159},
#   {'source': 'australia', 'target': 'south korea', 'weight': 0.071},
#   {'source': 'australia', 'target': 'us', 'weight': 0.054000000000000006},
#   {'source': 'australia', 'target': 'india', 'weight': 0.042},
#   {'source': 'djibouti', 'target': 'somalia', 'weight': 0.7979999999999999},
#   {'source': 'djibouti', 'target': 'us', 'weight': 0.054000000000000006},
#   {'source': 'djibouti', 'target': 'yemen', 'weight': 0.046},
#   {'source': 'djibouti', 'target': 'uae', 'weight': 0.04},
#   {'source': 'somalia', 'target': 'uae', 'weight': 0.45799999999999996},
#   {'source': 'somalia', 'target': 'yemen', 'weight': 0.19699999999999998},
#   {'source': 'somalia', 'target': 'oman', 'weight': 0.159},
#   {'source': 'yemen', 'target': 'china', 'weight': 0.245},
#   {'source': 'yemen', 'target': 'uae', 'weight': 0.165},
#   {'source': 'yemen', 'target': 'south korea', 'weight': 0.1},
#   {'source': 'yemen', 'target': 'saudi arabia', 'weight': 0.1},
#   {'source': 'yemen', 'target': 'kuwait', 'weight': 0.091},
#   {'source': 'yemen', 'target': 'india', 'weight': 0.085},
#   {'source': 'egypt', 'target': 'saudi arabia', 'weight': 0.091},
#   {'source': 'egypt', 'target': 'italy', 'weight': 0.075},
#   {'source': 'egypt', 'target': 'turkey', 'weight': 0.057999999999999996},
#   {'source': 'egypt', 'target': 'uae', 'weight': 0.051},
#   {'source': 'egypt', 'target': 'us', 'weight': 0.051},
#   {'source': 'egypt', 'target': 'uk', 'weight': 0.044000000000000004},
#   {'source': 'egypt', 'target': 'india', 'weight': 0.040999999999999995},
#   {'source': 'turkey', 'target': 'germany', 'weight': 0.09300000000000001},
#   {'source': 'turkey', 'target': 'uk', 'weight': 0.073},
#   {'source': 'turkey', 'target': 'iraq', 'weight': 0.059000000000000004},
#   {'source': 'turkey', 'target': 'italy', 'weight': 0.048},
#   {'source': 'turkey', 'target': 'us', 'weight': 0.045},
#   {'source': 'turkey', 'target': 'france', 'weight': 0.040999999999999995},
#   {'source': 'equatorial guinea', 'target': 'china', 'weight': 0.166},
#   {'source': 'equatorial guinea', 'target': 'south korea', 'weight': 0.151},
#   {'source': 'equatorial guinea', 'target': 'spain', 'weight': 0.09},
#   {'source': 'equatorial guinea',
#    'target': 'brazil',
#    'weight': 0.08199999999999999},
#   {'source': 'equatorial guinea', 'target': 'netherlands', 'weight': 0.068},
#   {'source': 'equatorial guinea', 'target': 'south africa', 'weight': 0.066},
#   {'source': 'equatorial guinea',
#    'target': 'india',
#    'weight': 0.057999999999999996},
#   {'source': 'equatorial guinea', 'target': 'uk', 'weight': 0.057},
#   {'source': 'equatorial guinea', 'target': 'france', 'weight': 0.057},
#   {'source': 'ethiopia',
#    'target': 'switzerland',
#    'weight': 0.14300000000000002},
#   {'source': 'ethiopia', 'target': 'china', 'weight': 0.11699999999999999},
#   {'source': 'ethiopia', 'target': 'us', 'weight': 0.095},
#   {'source': 'ethiopia',
#    'target': 'netherlands',
#    'weight': 0.08800000000000001},
#   {'source': 'ethiopia',
#    'target': 'saudi arabia',
#    'weight': 0.059000000000000004},
#   {'source': 'ethiopia', 'target': 'germany', 'weight': 0.057},
#   {'source': 'switzerland', 'target': 'germany', 'weight': 0.142},
#   {'source': 'switzerland', 'target': 'us', 'weight': 0.106},
#   {'source': 'switzerland', 'target': 'hong kong', 'weight': 0.087},
#   {'source': 'switzerland', 'target': 'india', 'weight': 0.073},
#   {'source': 'switzerland', 'target': 'china', 'weight': 0.069},
#   {'source': 'switzerland', 'target': 'france', 'weight': 0.061},
#   {'source': 'switzerland', 'target': 'italy', 'weight': 0.054000000000000006},
#   {'source': 'switzerland', 'target': 'uk', 'weight': 0.048},
#   {'source': 'the gambia', 'target': 'china', 'weight': 0.47600000000000003},
#   {'source': 'the gambia', 'target': 'india', 'weight': 0.272},
#   {'source': 'the gambia', 'target': 'france', 'weight': 0.059000000000000004},
#   {'source': 'the gambia', 'target': 'uk', 'weight': 0.049},
#   {'source': 'trinidad and tobago', 'target': 'us', 'weight': 0.263},
#   {'source': 'trinidad and tobago', 'target': 'argentina', 'weight': 0.12},
#   {'source': 'trinidad and tobago', 'target': 'brazil', 'weight': 0.066},
#   {'source': 'trinidad and tobago', 'target': 'chile', 'weight': 0.053},
#   {'source': 'trinidad and tobago',
#    'target': 'dominican republic',
#    'weight': 0.052000000000000005},
#   {'source': 'trinidad and tobago', 'target': 'barbados', 'weight': 0.05},
#   {'source': 'ghana', 'target': 'india', 'weight': 0.252},
#   {'source': 'ghana', 'target': 'switzerland', 'weight': 0.122},
#   {'source': 'ghana', 'target': 'china', 'weight': 0.106},
#   {'source': 'ghana', 'target': 'france', 'weight': 0.057},
#   {'source': 'guinea', 'target': 'india', 'weight': 0.225},
#   {'source': 'guinea', 'target': 'spain', 'weight': 0.08199999999999999},
#   {'source': 'guinea', 'target': 'ireland', 'weight': 0.073},
#   {'source': 'guinea', 'target': 'germany', 'weight': 0.062},
#   {'source': 'guinea', 'target': 'belgium', 'weight': 0.055},
#   {'source': 'guinea', 'target': 'ukraine', 'weight': 0.053},
#   {'source': 'guinea', 'target': 'france', 'weight': 0.040999999999999995},
#   {'source': 'ireland', 'target': 'us', 'weight': 0.237},
#   {'source': 'ireland', 'target': 'uk', 'weight': 0.138},
#   {'source': 'ireland', 'target': 'belgium', 'weight': 0.132},
#   {'source': 'ireland', 'target': 'germany', 'weight': 0.066},
#   {'source': 'ireland', 'target': 'switzerland', 'weight': 0.055},
#   {'source': 'ireland',
#    'target': 'netherlands',
#    'weight': 0.044000000000000004},
#   {'source': 'ireland', 'target': 'france', 'weight': 0.044000000000000004},
#   {'source': 'ukraine', 'target': 'russia', 'weight': 0.127},
#   {'source': 'ukraine', 'target': 'turkey', 'weight': 0.073},
#   {'source': 'ukraine', 'target': 'china', 'weight': 0.063},
#   {'source': 'ukraine', 'target': 'egypt', 'weight': 0.055},
#   {'source': 'ukraine', 'target': 'italy', 'weight': 0.052000000000000005},
#   {'source': 'ukraine', 'target': 'poland', 'weight': 0.052000000000000005},
#   {'source': "cote d'ivoire", 'target': 'us', 'weight': 0.085},
#   {'source': "cote d'ivoire", 'target': 'netherlands', 'weight': 0.062},
#   {'source': "cote d'ivoire",
#    'target': 'france',
#    'weight': 0.055999999999999994},
#   {'source': "cote d'ivoire",
#    'target': 'germany',
#    'weight': 0.055999999999999994},
#   {'source': "cote d'ivoire", 'target': 'nigeria', 'weight': 0.055},
#   {'source': "cote d'ivoire", 'target': 'burkina faso', 'weight': 0.055},
#   {'source': "cote d'ivoire", 'target': 'belgium', 'weight': 0.053},
#   {'source': "cote d'ivoire", 'target': 'india', 'weight': 0.046},
#   {'source': "cote d'ivoire",
#    'target': 'ghana',
#    'weight': 0.044000000000000004},
#   {'source': "cote d'ivoire",
#    'target': 'switzerland',
#    'weight': 0.040999999999999995},
#   {'source': 'burkina faso',
#    'target': 'switzerland',
#    'weight': 0.5329999999999999},
#   {'source': 'burkina faso', 'target': 'india', 'weight': 0.145},
#   {'source': 'kenya', 'target': 'uganda', 'weight': 0.11199999999999999},
#   {'source': 'kenya', 'target': 'us', 'weight': 0.083},
#   {'source': 'kenya', 'target': 'tanzania', 'weight': 0.081},
#   {'source': 'kenya', 'target': 'netherlands', 'weight': 0.07400000000000001},
#   {'source': 'kenya', 'target': 'uk', 'weight': 0.06},
#   {'source': 'kenya', 'target': 'pakistan', 'weight': 0.042},
#   {'source': 'tanzania', 'target': 'india', 'weight': 0.214},
#   {'source': 'tanzania', 'target': 'china', 'weight': 0.081},
#   {'source': 'tanzania', 'target': 'japan', 'weight': 0.051},
#   {'source': 'tanzania', 'target': 'kenya', 'weight': 0.046},
#   {'source': 'tanzania', 'target': 'belgium', 'weight': 0.043},
#   {'source': 'liberia', 'target': 'poland', 'weight': 0.32899999999999996},
#   {'source': 'liberia', 'target': 'china', 'weight': 0.207},
#   {'source': 'liberia', 'target': 'india', 'weight': 0.09300000000000001},
#   {'source': 'liberia', 'target': 'us', 'weight': 0.051},
#   {'source': 'liberia', 'target': 'greece', 'weight': 0.047},
#   {'source': 'liberia', 'target': 'france', 'weight': 0.043},
#   {'source': 'poland', 'target': 'germany', 'weight': 0.271},
#   {'source': 'poland', 'target': 'uk', 'weight': 0.068},
#   {'source': 'poland', 'target': 'czech republic', 'weight': 0.066},
#   {'source': 'poland', 'target': 'france', 'weight': 0.055},
#   {'source': 'poland', 'target': 'italy', 'weight': 0.048},
#   {'source': 'poland',
#    'target': 'netherlands',
#    'weight': 0.044000000000000004},
#   {'source': 'greece', 'target': 'italy', 'weight': 0.11199999999999999},
#   {'source': 'greece', 'target': 'germany', 'weight': 0.073},
#   {'source': 'greece', 'target': 'turkey', 'weight': 0.066},
#   {'source': 'greece', 'target': 'cyprus', 'weight': 0.059000000000000004},
#   {'source': 'greece', 'target': 'bulgaria', 'weight': 0.052000000000000005},
#   {'source': 'greece', 'target': 'us', 'weight': 0.048},
#   {'source': 'greece', 'target': 'uk', 'weight': 0.042},
#   {'source': 'greece', 'target': 'egypt', 'weight': 0.04},
#   {'source': 'libya', 'target': 'italy', 'weight': 0.321},
#   {'source': 'libya', 'target': 'germany', 'weight': 0.113},
#   {'source': 'libya', 'target': 'china', 'weight': 0.08},
#   {'source': 'libya', 'target': 'france', 'weight': 0.08},
#   {'source': 'libya', 'target': 'spain', 'weight': 0.055999999999999994},
#   {'source': 'libya', 'target': 'netherlands', 'weight': 0.054000000000000006},
#   {'source': 'libya', 'target': 'syria', 'weight': 0.053},
#   {'source': 'syria', 'target': 'iraq', 'weight': 0.647},
#   {'source': 'syria', 'target': 'saudi arabia', 'weight': 0.11199999999999999},
#   {'source': 'syria', 'target': 'kuwait', 'weight': 0.071},
#   {'source': 'syria', 'target': 'uae', 'weight': 0.061},
#   {'source': 'syria', 'target': 'libya', 'weight': 0.046},
#   {'source': 'madagascar', 'target': 'france', 'weight': 0.152},
#   {'source': 'madagascar', 'target': 'us', 'weight': 0.127},
#   {'source': 'madagascar', 'target': 'china', 'weight': 0.071},
#   {'source': 'madagascar',
#    'target': 'south africa',
#    'weight': 0.059000000000000004},
#   {'source': 'madagascar', 'target': 'japan', 'weight': 0.055},
#   {'source': 'madagascar',
#    'target': 'netherlands',
#    'weight': 0.054000000000000006},
#   {'source': 'madagascar', 'target': 'germany', 'weight': 0.051},
#   {'source': 'madagascar', 'target': 'belgium', 'weight': 0.05},
#   {'source': 'madagascar', 'target': 'india', 'weight': 0.044000000000000004},
#   {'source': 'malawi', 'target': 'belgium', 'weight': 0.158},
#   {'source': 'malawi', 'target': 'zimbabwe', 'weight': 0.12},
#   {'source': 'malawi', 'target': 'india', 'weight': 0.069},
#   {'source': 'malawi', 'target': 'south africa', 'weight': 0.062},
#   {'source': 'malawi', 'target': 'us', 'weight': 0.06},
#   {'source': 'malawi', 'target': 'russia', 'weight': 0.055999999999999994},
#   {'source': 'malawi', 'target': 'germany', 'weight': 0.046},
#   {'source': 'zimbabwe', 'target': 'china', 'weight': 0.278},
#   {'source': 'zimbabwe',
#    'target': 'democratic republic of the congo',
#    'weight': 0.14},
#   {'source': 'zimbabwe', 'target': 'botswana', 'weight': 0.125},
#   {'source': 'zimbabwe', 'target': 'south africa', 'weight': 0.076},
#   {'source': 'russia', 'target': 'netherlands', 'weight': 0.11900000000000001},
#   {'source': 'russia', 'target': 'china', 'weight': 0.083},
#   {'source': 'russia', 'target': 'germany', 'weight': 0.07400000000000001},
#   {'source': 'russia', 'target': 'italy', 'weight': 0.065},
#   {'source': 'russia', 'target': 'turkey', 'weight': 0.055999999999999994},
#   {'source': 'russia', 'target': 'belarus', 'weight': 0.044000000000000004},
#   {'source': 'russia', 'target': 'japan', 'weight': 0.042},
#   {'source': 'mali', 'target': 'switzerland', 'weight': 0.485},
#   {'source': 'mali', 'target': 'china', 'weight': 0.094},
#   {'source': 'mali', 'target': 'india', 'weight': 0.091},
#   {'source': 'mali', 'target': 'bangladesh', 'weight': 0.08},
#   {'source': 'mali', 'target': 'thailand', 'weight': 0.045},
#   {'source': 'mali', 'target': 'indonesia', 'weight': 0.044000000000000004},
#   {'source': 'thailand', 'target': 'us', 'weight': 0.11199999999999999},
#   {'source': 'thailand', 'target': 'china', 'weight': 0.111},
#   {'source': 'thailand', 'target': 'japan', 'weight': 0.094},
#   {'source': 'thailand', 'target': 'hong kong', 'weight': 0.055},
#   {'source': 'thailand', 'target': 'malaysia', 'weight': 0.048},
#   {'source': 'thailand', 'target': 'australia', 'weight': 0.046},
#   {'source': 'thailand', 'target': 'vietnam', 'weight': 0.042},
#   {'source': 'thailand',
#    'target': 'singapore',
#    'weight': 0.040999999999999995},
#   {'source': 'indonesia', 'target': 'japan', 'weight': 0.12},
#   {'source': 'indonesia', 'target': 'us', 'weight': 0.10800000000000001},
#   {'source': 'indonesia', 'target': 'china', 'weight': 0.1},
#   {'source': 'indonesia', 'target': 'singapore', 'weight': 0.084},
#   {'source': 'indonesia', 'target': 'india', 'weight': 0.078},
#   {'source': 'indonesia', 'target': 'south korea', 'weight': 0.051},
#   {'source': 'indonesia', 'target': 'malaysia', 'weight': 0.051},
#   {'source': 'morocco', 'target': 'spain', 'weight': 0.221},
#   {'source': 'morocco', 'target': 'france', 'weight': 0.19699999999999998},
#   {'source': 'morocco', 'target': 'india', 'weight': 0.049},
#   {'source': 'morocco', 'target': 'us', 'weight': 0.043},
#   {'source': 'morocco', 'target': 'italy', 'weight': 0.043},
#   {'source': 'mauritania', 'target': 'china', 'weight': 0.327},
#   {'source': 'mauritania', 'target': 'switzerland', 'weight': 0.111},
#   {'source': 'mauritania', 'target': 'spain', 'weight': 0.086},
#   {'source': 'mauritania', 'target': 'italy', 'weight': 0.067},
#   {'source': 'mauritania', 'target': 'cote divoire', 'weight': 0.066},
#   {'source': 'mauritania', 'target': 'japan', 'weight': 0.057},
#   {'source': 'mozambique', 'target': 'south africa', 'weight': 0.249},
#   {'source': 'mozambique', 'target': 'china', 'weight': 0.102},
#   {'source': 'mozambique', 'target': 'italy', 'weight': 0.08900000000000001},
#   {'source': 'mozambique', 'target': 'india', 'weight': 0.08900000000000001},
#   {'source': 'mozambique', 'target': 'belgium', 'weight': 0.079},
#   {'source': 'mozambique', 'target': 'spain', 'weight': 0.044000000000000004},
#   {'source': 'guinea-bissau', 'target': 'india', 'weight': 0.635},
#   {'source': 'guinea-bissau', 'target': 'nigeria', 'weight': 0.203},
#   {'source': 'guinea-bissau', 'target': 'china', 'weight': 0.057},
#   {'source': 'guinea-bissau',
#    'target': 'togo',
#    'weight': 0.055999999999999994},
#   {'source': 'togo', 'target': 'india', 'weight': 0.146},
#   {'source': 'togo', 'target': 'burkina faso', 'weight': 0.113},
#   {'source': 'togo', 'target': 'china', 'weight': 0.113},
#   {'source': 'togo', 'target': 'benin', 'weight': 0.096},
#   {'source': 'togo', 'target': 'ghana', 'weight': 0.09},
#   {'source': 'togo', 'target': 'lebanon', 'weight': 0.083},
#   {'source': 'togo', 'target': 'nigeria', 'weight': 0.061},
#   {'source': 'togo', 'target': 'niger', 'weight': 0.059000000000000004},
#   {'source': 'malaysia', 'target': 'singapore', 'weight': 0.139},
#   {'source': 'malaysia', 'target': 'china', 'weight': 0.13},
#   {'source': 'malaysia', 'target': 'japan', 'weight': 0.095},
#   {'source': 'malaysia', 'target': 'us', 'weight': 0.094},
#   {'source': 'malaysia', 'target': 'thailand', 'weight': 0.057},
#   {'source': 'malaysia', 'target': 'hong kong', 'weight': 0.047},
#   {'source': 'malaysia', 'target': 'india', 'weight': 0.040999999999999995},
#   {'source': 'seychelles', 'target': 'france', 'weight': 0.182},
#   {'source': 'seychelles', 'target': 'uk', 'weight': 0.179},
#   {'source': 'seychelles', 'target': 'mauritius', 'weight': 0.1},
#   {'source': 'seychelles', 'target': 'japan', 'weight': 0.092},
#   {'source': 'seychelles', 'target': 'italy', 'weight': 0.078},
#   {'source': 'seychelles', 'target': 'spain', 'weight': 0.045},
#   {'source': 'senegal', 'target': 'mali', 'weight': 0.128},
#   {'source': 'senegal',
#    'target': 'switzerland',
#    'weight': 0.09699999999999999},
#   {'source': 'senegal', 'target': 'india', 'weight': 0.059000000000000004},
#   {'source': 'senegal', 'target': 'cote divoire', 'weight': 0.053},
#   {'source': 'senegal', 'target': 'china', 'weight': 0.051},
#   {'source': 'senegal', 'target': 'uae', 'weight': 0.040999999999999995},
#   {'source': 'senegal', 'target': 'france', 'weight': 0.040999999999999995},
#   {'source': 'sierra leone', 'target': 'china', 'weight': 0.313},
#   {'source': 'sierra leone', 'target': 'belgium', 'weight': 0.278},
#   {'source': 'sierra leone', 'target': 'romania', 'weight': 0.113},
#   {'source': 'sierra leone', 'target': 'us', 'weight': 0.073},
#   {'source': 'sierra leone', 'target': 'india', 'weight': 0.04},
#   {'source': 'romania', 'target': 'germany', 'weight': 0.198},
#   {'source': 'romania', 'target': 'italy', 'weight': 0.125},
#   {'source': 'romania', 'target': 'france', 'weight': 0.068},
#   {'source': 'romania', 'target': 'hungary', 'weight': 0.054000000000000006},
#   {'source': 'romania', 'target': 'uk', 'weight': 0.044000000000000004},
#   {'source': 'oman', 'target': 'china', 'weight': 0.354},
#   {'source': 'oman', 'target': 'uae', 'weight': 0.153},
#   {'source': 'oman', 'target': 'south korea', 'weight': 0.068},
#   {'source': 'oman', 'target': 'saudi arabia', 'weight': 0.057999999999999996},
#   {'source': 'oman', 'target': 'pakistan', 'weight': 0.042},
#   {'source': 'sudan', 'target': 'uae', 'weight': 0.32},
#   {'source': 'sudan', 'target': 'china', 'weight': 0.162},
#   {'source': 'sudan', 'target': 'saudi arabia', 'weight': 0.155},
#   {'source': 'sudan', 'target': 'australia', 'weight': 0.047},
#   {'source': 'sudan', 'target': 'india', 'weight': 0.042},
#   {'source': 'lebanon', 'target': 'saudi arabia', 'weight': 0.121},
#   {'source': 'lebanon', 'target': 'uae', 'weight': 0.106},
#   {'source': 'lebanon', 'target': 'iraq', 'weight': 0.076},
#   {'source': 'lebanon', 'target': 'syria', 'weight': 0.071},
#   {'source': 'lebanon', 'target': 'south africa', 'weight': 0.066},
#   {'source': 'sao tome and principe',
#    'target': 'netherlands',
#    'weight': 0.292},
#   {'source': 'sao tome and principe',
#    'target': 'belgium',
#    'weight': 0.22399999999999998},
#   {'source': 'sao tome and principe', 'target': 'spain', 'weight': 0.155},
#   {'source': 'sao tome and principe', 'target': 'us', 'weight': 0.066},
#   {'source': 'sao tome and principe', 'target': 'nigeria', 'weight': 0.051},
#   {'source': 'american samoa', 'target': 'us', 'weight': 1.0},
#   {'source': 'solomon islands', 'target': 'china', 'weight': 0.617},
#   {'source': 'solomon islands',
#    'target': 'india',
#    'weight': 0.059000000000000004},
#   {'source': 'solomon islands',
#    'target': 'italy',
#    'weight': 0.059000000000000004},
#   {'source': 'fiji', 'target': 'us', 'weight': 0.134},
#   {'source': 'fiji', 'target': 'australia', 'weight': 0.102},
#   {'source': 'fiji', 'target': 'samoa', 'weight': 0.067},
#   {'source': 'fiji', 'target': 'tonga', 'weight': 0.059000000000000004},
#   {'source': 'samoa',
#    'target': 'american samoa',
#    'weight': 0.5710000000000001},
#   {'source': 'samoa', 'target': 'australia', 'weight': 0.172},
#   {'source': 'tonga', 'target': 'japan', 'weight': 0.16},
#   {'source': 'tonga', 'target': 'us', 'weight': 0.154},
#   {'source': 'tonga', 'target': 'fiji', 'weight': 0.128},
#   {'source': 'tonga', 'target': 'nz', 'weight': 0.125},
#   {'source': 'tonga', 'target': 'south korea', 'weight': 0.11},
#   {'source': 'tonga', 'target': 'samoa', 'weight': 0.107},
#   {'source': 'tonga', 'target': 'australia', 'weight': 0.075},
#   {'source': 'tonga', 'target': 'american samoa', 'weight': 0.068},
#   {'source': 'french polynesia', 'target': 'japan', 'weight': 0.35},
#   {'source': 'french polynesia', 'target': 'us', 'weight': 0.24},
#   {'source': 'french polynesia', 'target': 'hong kong', 'weight': 0.17},
#   {'source': 'french polynesia', 'target': 'france', 'weight': 0.091},
#   {'source': 'french polynesia', 'target': 'china', 'weight': 0.042},
#   {'source': 'hong kong', 'target': 'china', 'weight': 0.537},
#   {'source': 'hong kong', 'target': 'us', 'weight': 0.095},
#   {'source': 'new caledonia', 'target': 'china', 'weight': 0.318},
#   {'source': 'new caledonia', 'target': 'japan', 'weight': 0.152},
#   {'source': 'new caledonia', 'target': 'south korea', 'weight': 0.107},
#   {'source': 'new caledonia', 'target': 'australia', 'weight': 0.081},
#   {'source': 'new caledonia',
#    'target': 'france',
#    'weight': 0.07400000000000001},
#   {'source': 'new caledonia', 'target': 'belgium', 'weight': 0.051},
#   {'source': 'niue', 'target': 'germany', 'weight': 0.25},
#   {'source': 'niue', 'target': 'belgium', 'weight': 0.11},
#   {'source': 'niue', 'target': 'united kingdom', 'weight': 0.08},
#   {'source': 'niue', 'target': 'france', 'weight': 0.08},
#   {'source': 'niue', 'target': 'italy', 'weight': 0.04},
#   {'source': 'niue', 'target': 'united states', 'weight': 0.04},
#   {'source': 'united kingdom', 'target': 'us', 'weight': 0.146},
#   {'source': 'united kingdom',
#    'target': 'germany',
#    'weight': 0.10099999999999999},
#   {'source': 'united kingdom', 'target': 'switzerland', 'weight': 0.07},
#   {'source': 'united kingdom', 'target': 'china', 'weight': 0.06},
#   {'source': 'united kingdom',
#    'target': 'france',
#    'weight': 0.059000000000000004},
#   {'source': 'united kingdom',
#    'target': 'netherlands',
#    'weight': 0.057999999999999996},
#   {'source': 'united kingdom', 'target': 'ireland', 'weight': 0.055},
#   {'source': 'united states',
#    'target': 'canada',
#    'weight': 0.18600000000000003},
#   {'source': 'united states', 'target': 'mexico', 'weight': 0.157},
#   {'source': 'united states', 'target': 'china', 'weight': 0.077},
#   {'source': 'united states', 'target': 'japan', 'weight': 0.042},
#   {'source': 'vanuatu', 'target': 'japan', 'weight': 0.35100000000000003},
#   {'source': 'vanuatu', 'target': 'turkey', 'weight': 0.105},
#   {'source': 'vanuatu', 'target': 'thailand', 'weight': 0.087},
#   {'source': 'vanuatu', 'target': 'china', 'weight': 0.08199999999999999},
#   {'source': 'vanuatu', 'target': 'venezuela', 'weight': 0.059000000000000004},
#   {'source': 'vanuatu', 'target': 'uk', 'weight': 0.055999999999999994},
#   {'source': 'venezuela', 'target': 'us', 'weight': 0.266},
#   {'source': 'venezuela', 'target': 'india', 'weight': 0.13699999999999998},
#   {'source': 'venezuela', 'target': 'china', 'weight': 0.11699999999999999},
#   {'source': 'venezuela', 'target': 'cuba', 'weight': 0.064},
#   {'source': 'new zealand', 'target': 'china', 'weight': 0.175},
#   {'source': 'new zealand',
#    'target': 'australia',
#    'weight': 0.16899999999999998},
#   {'source': 'new zealand', 'target': 'us', 'weight': 0.11800000000000001},
#   {'source': 'new zealand', 'target': 'japan', 'weight': 0.06},
#   {'source': 'aruba', 'target': 'colombia', 'weight': 0.282},
#   {'source': 'aruba',
#    'target': 'netherlands antilles',
#    'weight': 0.18100000000000002},
#   {'source': 'aruba', 'target': 'us', 'weight': 0.14300000000000002},
#   {'source': 'aruba', 'target': 'netherlands', 'weight': 0.10099999999999999},
#   {'source': 'aruba', 'target': 'mexico', 'weight': 0.065},
#   {'source': 'aruba', 'target': 'venezuela', 'weight': 0.063},
#   {'source': 'aruba', 'target': 'panama', 'weight': 0.040999999999999995},
#   {'source': 'colombia', 'target': 'us', 'weight': 0.275},
#   {'source': 'colombia', 'target': 'panama', 'weight': 0.07200000000000001},
#   {'source': 'colombia', 'target': 'china', 'weight': 0.052000000000000005},
#   {'source': 'colombia', 'target': 'spain', 'weight': 0.044000000000000004},
#   {'source': 'colombia', 'target': 'ecuador', 'weight': 0.04},
#   {'source': 'mexico', 'target': 'us', 'weight': 0.8109999999999999},
#   {'source': 'panama', 'target': 'us', 'weight': 0.19699999999999998},
#   {'source': 'panama', 'target': 'germany', 'weight': 0.132},
#   {'source': 'panama', 'target': 'costa rica', 'weight': 0.077},
#   {'source': 'panama', 'target': 'china', 'weight': 0.059000000000000004},
#   {'source': 'panama',
#    'target': 'netherlands',
#    'weight': 0.040999999999999995},
#   {'source': 'barbados', 'target': 'trinidad and tobago', 'weight': 0.225},
#   {'source': 'barbados', 'target': 'us', 'weight': 0.11800000000000001},
#   {'source': 'barbados', 'target': 'st. lucia', 'weight': 0.092},
#   {'source': 'barbados',
#    'target': 'st. vincent and the grenadines',
#    'weight': 0.057},
#   {'source': 'barbados', 'target': 'antigua and barbuda', 'weight': 0.047},
#   {'source': 'barbados',
#    'target': 'st. kitts and nevis',
#    'weight': 0.044000000000000004},
#   {'source': 'barbados', 'target': 'guyana', 'weight': 0.042},
#   {'source': 'guyana', 'target': 'us', 'weight': 0.335},
#   {'source': 'guyana', 'target': 'canada', 'weight': 0.179},
#   {'source': 'guyana', 'target': 'uk', 'weight': 0.067},
#   {'source': 'guyana', 'target': 'ukraine', 'weight': 0.043},
#   {'source': 'guyana', 'target': 'jamaica', 'weight': 0.04},
#   {'source': 'the bahamas', 'target': 'poland', 'weight': 0.263},
#   {'source': 'the bahamas', 'target': 'cote divoire', 'weight': 0.209},
#   {'source': 'the bahamas', 'target': 'us', 'weight': 0.159},
#   {'source': 'the bahamas',
#    'target': 'dominican republic',
#    'weight': 0.14300000000000002},
#   {'source': 'belize', 'target': 'uk', 'weight': 0.308},
#   {'source': 'belize', 'target': 'us', 'weight': 0.187},
#   {'source': 'belize', 'target': 'nigeria', 'weight': 0.067},
#   {'source': 'belize', 'target': 'trinidad and tobago', 'weight': 0.048},
#   {'source': 'belize', 'target': 'ireland', 'weight': 0.042},
#   {'source': 'belize', 'target': 'jamaica', 'weight': 0.042},
#   {'source': 'jamaica', 'target': 'us', 'weight': 0.244},
#   {'source': 'jamaica', 'target': 'canada', 'weight': 0.165},
#   {'source': 'jamaica', 'target': 'russia', 'weight': 0.09300000000000001},
#   {'source': 'jamaica',
#    'target': 'netherlands',
#    'weight': 0.08900000000000001},
#   {'source': 'jamaica', 'target': 'iceland', 'weight': 0.07200000000000001},
#   {'source': 'jamaica', 'target': 'uk', 'weight': 0.065},
#   {'source': 'costa rica', 'target': 'us', 'weight': 0.336},
#   {'source': 'costa rica', 'target': 'china', 'weight': 0.062},
#   {'source': 'costa rica', 'target': 'mexico', 'weight': 0.046},
#   {'source': 'costa rica', 'target': 'nicaragua', 'weight': 0.043},
#   {'source': 'costa rica', 'target': 'netherlands', 'weight': 0.042},
#   {'source': 'costa rica', 'target': 'guatemala', 'weight': 0.04},
#   {'source': 'nicaragua', 'target': 'us', 'weight': 0.565},
#   {'source': 'nicaragua', 'target': 'mexico', 'weight': 0.107},
#   {'source': 'nicaragua',
#    'target': 'venezuela',
#    'weight': 0.054000000000000006},
#   {'source': 'nicaragua', 'target': 'el salvador', 'weight': 0.043},
#   {'source': 'guatemala', 'target': 'us', 'weight': 0.349},
#   {'source': 'guatemala', 'target': 'el salvador', 'weight': 0.084},
#   {'source': 'guatemala', 'target': 'honduras', 'weight': 0.073},
#   {'source': 'guatemala', 'target': 'nicaragua', 'weight': 0.05},
#   {'source': 'guatemala', 'target': 'canada', 'weight': 0.046},
#   {'source': 'guatemala', 'target': 'mexico', 'weight': 0.043},
#   {'source': 'guatemala',
#    'target': 'costa rica',
#    'weight': 0.040999999999999995},
#   {'source': 'cuba', 'target': 'canada', 'weight': 0.177},
#   {'source': 'cuba', 'target': 'venezuela', 'weight': 0.138},
#   {'source': 'cuba', 'target': 'china', 'weight': 0.13},
#   {'source': 'cuba', 'target': 'netherlands', 'weight': 0.064},
#   {'source': 'cuba', 'target': 'spain', 'weight': 0.054000000000000006},
#   {'source': 'cuba', 'target': 'belize', 'weight': 0.047},
#   {'source': 'canada', 'target': 'us', 'weight': 0.767},
#   {'source': 'dominica', 'target': 'japan', 'weight': 0.381},
#   {'source': 'dominica', 'target': 'jamaica', 'weight': 0.19},
#   {'source': 'dominica',
#    'target': 'antigua and barbuda',
#    'weight': 0.10400000000000001},
#   {'source': 'dominica', 'target': 'trinidad and tobago', 'weight': 0.062},
#   {'source': 'dominica', 'target': 'st. lucia', 'weight': 0.048},
#   {'source': 'dominica', 'target': 'st. kitts and nevis', 'weight': 0.042},
#   {'source': 'the dominican', 'target': 'us', 'weight': 0.425},
#   {'source': 'the dominican', 'target': 'haiti', 'weight': 0.165},
#   {'source': 'the dominican', 'target': 'canada', 'weight': 0.081},
#   {'source': 'the dominican', 'target': 'india', 'weight': 0.048},
#   {'source': 'haiti', 'target': 'us', 'weight': 0.853},
#   {'source': 'el salvador', 'target': 'us', 'weight': 0.47100000000000003},
#   {'source': 'el salvador', 'target': 'honduras', 'weight': 0.139},
#   {'source': 'el salvador', 'target': 'guatemala', 'weight': 0.136},
#   {'source': 'el salvador', 'target': 'nicaragua', 'weight': 0.066},
#   {'source': 'el salvador', 'target': 'costa rica', 'weight': 0.045},
#   {'source': 'honduras', 'target': 'us', 'weight': 0.36},
#   {'source': 'honduras', 'target': 'germany', 'weight': 0.087},
#   {'source': 'honduras', 'target': 'el salvador', 'weight': 0.085},
#   {'source': 'honduras', 'target': 'guatemala', 'weight': 0.06},
#   {'source': 'honduras',
#    'target': 'nicaragua',
#    'weight': 0.055999999999999994},
#   {'source': 'honduras',
#    'target': 'netherlands',
#    'weight': 0.040999999999999995},
#   {'source': 'grenada', 'target': 'nigeria', 'weight': 0.447},
#   {'source': 'grenada', 'target': 'st. lucia', 'weight': 0.10800000000000001},
#   {'source': 'grenada', 'target': 'antigua and barbuda', 'weight': 0.073},
#   {'source': 'grenada', 'target': 'st. kitts and nevis', 'weight': 0.066},
#   {'source': 'grenada', 'target': 'dominica', 'weight': 0.066},
#   {'source': 'grenada', 'target': 'us', 'weight': 0.057999999999999996},
#   {'source': 'iceland', 'target': 'netherlands', 'weight': 0.261},
#   {'source': 'iceland', 'target': 'uk', 'weight': 0.11599999999999999},
#   {'source': 'iceland', 'target': 'spain', 'weight': 0.115},
#   {'source': 'iceland', 'target': 'germany', 'weight': 0.07400000000000001},
#   {'source': 'iceland', 'target': 'france', 'weight': 0.057},
#   {'source': 'iceland', 'target': 'us', 'weight': 0.057},
#   {'source': 'iceland', 'target': 'norway', 'weight': 0.047},
#   {'source': 'saint kitts and nevis', 'target': 'us', 'weight': 0.444},
#   {'source': 'saint kitts and nevis', 'target': 'poland', 'weight': 0.146},
#   {'source': 'saint kitts and nevis',
#    'target': 'bangladesh',
#    'weight': 0.10099999999999999},
#   {'source': 'saint kitts and nevis', 'target': 'azerbaijan', 'weight': 0.043},
#   {'source': 'azerbaijan', 'target': 'italy', 'weight': 0.263},
#   {'source': 'azerbaijan', 'target': 'germany', 'weight': 0.133},
#   {'source': 'azerbaijan', 'target': 'indonesia', 'weight': 0.07},
#   {'source': 'azerbaijan', 'target': 'france', 'weight': 0.069},
#   {'source': 'azerbaijan', 'target': 'czech republic', 'weight': 0.06},
#   {'source': 'saint lucia', 'target': 'dominican republic', 'weight': 0.251},
#   {'source': 'saint lucia', 'target': 'us', 'weight': 0.159},
#   {'source': 'saint lucia', 'target': 'suriname', 'weight': 0.091},
#   {'source': 'saint lucia', 'target': 'antigua and barbuda', 'weight': 0.07},
#   {'source': 'saint lucia', 'target': 'dominica', 'weight': 0.068},
#   {'source': 'saint lucia', 'target': 'trinidad and tobago', 'weight': 0.063},
#   {'source': 'saint lucia', 'target': 'barbados', 'weight': 0.061},
#   {'source': 'saint lucia', 'target': 'uk', 'weight': 0.048},
#   {'source': 'saint lucia', 'target': 'grenada', 'weight': 0.046},
#   {'source': 'suriname', 'target': 'switzerland', 'weight': 0.218},
#   {'source': 'suriname', 'target': 'uae', 'weight': 0.145},
#   {'source': 'suriname', 'target': 'india', 'weight': 0.139},
#   {'source': 'suriname', 'target': 'belgium', 'weight': 0.09699999999999999},
#   {'source': 'suriname', 'target': 'us', 'weight': 0.08900000000000001},
#   {'source': 'suriname', 'target': 'france', 'weight': 0.081},
#   {'source': 'suriname', 'target': 'canada', 'weight': 0.066},
#   {'source': 'argentina', 'target': 'brazil', 'weight': 0.17},
#   {'source': 'argentina', 'target': 'china', 'weight': 0.086},
#   {'source': 'argentina', 'target': 'us', 'weight': 0.059000000000000004},
#   {'source': 'chile', 'target': 'china', 'weight': 0.263},
#   {'source': 'chile', 'target': 'us', 'weight': 0.132},
#   {'source': 'chile', 'target': 'japan', 'weight': 0.085},
# ...
#   {'source': 'finland', 'target': 'germany', 'weight': 0.139},
#   {'source': 'finland', 'target': 'sweden', 'weight': 0.10099999999999999},
#   {'source': 'finland', 'target': 'us', 'weight': 0.07},
#   {'source': 'finland', 'target': 'netherlands', 'weight': 0.066},
#   {'source': 'finland', 'target': 'russia', 'weight': 0.059000000000000004},
#   {'source': 'finland', 'target': 'uk', 'weight': 0.052000000000000005},
#   {'source': 'finland', 'target': 'china', 'weight': 0.047},
#   {'source': 'latvia', 'target': 'lithuania', 'weight': 0.17800000000000002},
#   {'source': 'latvia', 'target': 'russia', 'weight': 0.115},
#   {'source': 'latvia', 'target': 'estonia', 'weight': 0.111},
#   {'source': 'latvia', 'target': 'germany', 'weight': 0.063},
#   {'source': 'latvia', 'target': 'poland', 'weight': 0.055999999999999994},
#   {'source': 'latvia', 'target': 'sweden', 'weight': 0.052000000000000005},
#   {'source': 'latvia', 'target': 'uk', 'weight': 0.05},
#   {'source': 'latvia', 'target': 'denmark', 'weight': 0.04},
#   {'source': 'lithuania', 'target': 'russia', 'weight': 0.13699999999999998},
#   {'source': 'lithuania', 'target': 'latvia', 'weight': 0.098},
#   {'source': 'lithuania', 'target': 'poland', 'weight': 0.09699999999999999},
#   {'source': 'lithuania', 'target': 'germany', 'weight': 0.078},
#   {'source': 'lithuania', 'target': 'estonia', 'weight': 0.053},
#   {'source': 'lithuania', 'target': 'belarus', 'weight': 0.046},
#   {'source': 'lithuania', 'target': 'uk', 'weight': 0.045},
#   {'source': 'lithuania', 'target': 'us', 'weight': 0.044000000000000004},
#   {'source': 'lithuania', 'target': 'netherlands', 'weight': 0.04},
#   {'source': 'czechia', 'target': 'germany', 'weight': 0.324},
#   {'source': 'czechia', 'target': 'slovakia', 'weight': 0.09},
#   {'source': 'czechia', 'target': 'poland', 'weight': 0.057999999999999996},
#   {'source': 'czechia', 'target': 'uk', 'weight': 0.053},
#   {'source': 'czechia', 'target': 'france', 'weight': 0.051},
#   {'source': 'czechia', 'target': 'austria', 'weight': 0.040999999999999995},
#   {'source': 'faroe islands',
#    'target': 'russia',
#    'weight': 0.20199999999999999},
#   {'source': 'faroe islands', 'target': 'uk', 'weight': 0.166},
#   {'source': 'faroe islands', 'target': 'denmark', 'weight': 0.163},
#   {'source': 'faroe islands',
#    'target': 'nigeria',
#    'weight': 0.11599999999999999},
#   {'source': 'faroe islands',
#    'target': 'china',
#    'weight': 0.09300000000000001},
#   {'source': 'faroe islands', 'target': 'us', 'weight': 0.07200000000000001},
#   {'source': 'faroe islands',
#    'target': 'netherlands',
#    'weight': 0.055999999999999994},
#   {'source': 'faroe islands', 'target': 'norway', 'weight': 0.04},
#   {'source': 'serbia', 'target': 'italy', 'weight': 0.162},
#   {'source': 'serbia', 'target': 'germany', 'weight': 0.126},
#   {'source': 'serbia', 'target': 'bosnia and herzegovina', 'weight': 0.087},
#   {'source': 'serbia', 'target': 'romania', 'weight': 0.055999999999999994},
#   {'source': 'serbia', 'target': 'russia', 'weight': 0.054000000000000006},
#   {'source': 'hungary', 'target': 'germany', 'weight': 0.28},
#   {'source': 'hungary', 'target': 'romania', 'weight': 0.054000000000000006},
#   {'source': 'hungary', 'target': 'slovakia', 'weight': 0.051},
#   {'source': 'hungary', 'target': 'austria', 'weight': 0.05},
#   {'source': 'hungary', 'target': 'italy', 'weight': 0.048},
#   {'source': 'hungary', 'target': 'france', 'weight': 0.047},
#   {'source': 'hungary', 'target': 'uk', 'weight': 0.04},
#   {'source': 'hungary', 'target': 'czech republic', 'weight': 0.04},
#   {'source': 'macedonia', 'target': 'germany', 'weight': 0.332},
#   {'source': 'macedonia', 'target': 'kosovo', 'weight': 0.115},
#   {'source': 'macedonia', 'target': 'bulgaria', 'weight': 0.051},
#   {'source': 'macedonia', 'target': 'greece', 'weight': 0.045},
#   {'source': 'luxembourg', 'target': 'germany', 'weight': 0.221},
#   {'source': 'luxembourg', 'target': 'belgium', 'weight': 0.16699999999999998},
#   {'source': 'luxembourg', 'target': 'france', 'weight': 0.166},
#   {'source': 'luxembourg', 'target': 'uk', 'weight': 0.047},
#   {'source': 'luxembourg', 'target': 'italy', 'weight': 0.046},
#   {'source': 'luxembourg', 'target': 'netherlands', 'weight': 0.04},
#   {'source': 'moldova', 'target': 'romania', 'weight': 0.231},
#   {'source': 'moldova', 'target': 'italy', 'weight': 0.102},
#   {'source': 'moldova', 'target': 'turkey', 'weight': 0.094},
#   {'source': 'moldova', 'target': 'russia', 'weight': 0.08},
#   {'source': 'moldova', 'target': 'germany', 'weight': 0.066},
#   {'source': 'moldova', 'target': 'belarus', 'weight': 0.064},
#   {'source': 'montenegro', 'target': 'croatia', 'weight': 0.22699999999999998},
#   {'source': 'montenegro', 'target': 'serbia', 'weight': 0.22699999999999998},
#   {'source': 'montenegro', 'target': 'slovenia', 'weight': 0.078},
#   {'source': 'monaco', 'target': 'europe', 'weight': 0.732},
#   {'source': 'monaco', 'target': 'africa', 'weight': 0.146},
#   {'source': 'monaco', 'target': 'america', 'weight': 0.052000000000000005},
#   {'source': 'monaco', 'target': 'asia', 'weight': 0.049},
#   {'source': 'malta', 'target': 'germany', 'weight': 0.133},
#   {'source': 'malta', 'target': 'france', 'weight': 0.102},
#   {'source': 'malta', 'target': 'hong kong', 'weight': 0.07400000000000001},
#   {'source': 'malta', 'target': 'singapore', 'weight': 0.073},
#   {'source': 'malta', 'target': 'uk', 'weight': 0.064},
#   {'source': 'malta', 'target': 'us', 'weight': 0.057999999999999996},
#   {'source': 'malta', 'target': 'italy', 'weight': 0.055999999999999994},
#   {'source': 'malta', 'target': 'japan', 'weight': 0.047},
#   {'source': 'san marino', 'target': 'italy', 'weight': 0.823},
#   {'source': 'armenia', 'target': 'russia', 'weight': 0.152},
#   {'source': 'armenia', 'target': 'china', 'weight': 0.111},
#   {'source': 'armenia', 'target': 'germany', 'weight': 0.098},
#   {'source': 'armenia', 'target': 'iraq', 'weight': 0.08800000000000001},
#   {'source': 'armenia', 'target': 'georgia', 'weight': 0.078},
#   {'source': 'armenia', 'target': 'canada', 'weight': 0.076},
#   {'source': 'armenia', 'target': 'bulgaria', 'weight': 0.053},
#   {'source': 'armenia', 'target': 'iran', 'weight': 0.053},
#   {'source': 'iraq', 'target': 'china', 'weight': 0.226},
#   {'source': 'iraq', 'target': 'india', 'weight': 0.21100000000000002},
#   {'source': 'iraq', 'target': 'south korea', 'weight': 0.11199999999999999},
#   {'source': 'iraq', 'target': 'us', 'weight': 0.078},
#   {'source': 'iraq', 'target': 'italy', 'weight': 0.067},
#   {'source': 'iraq', 'target': 'greece', 'weight': 0.06},
#   {'source': 'georgia', 'target': 'azerbaijan', 'weight': 0.109},
#   {'source': 'georgia', 'target': 'bulgaria', 'weight': 0.09699999999999999},
#   {'source': 'georgia', 'target': 'turkey', 'weight': 0.084},
#   {'source': 'georgia', 'target': 'armenia', 'weight': 0.08199999999999999},
#   {'source': 'georgia', 'target': 'russia', 'weight': 0.07400000000000001},
#   {'source': 'georgia', 'target': 'china', 'weight': 0.057},
#   {'source': 'georgia', 'target': 'us', 'weight': 0.047},
#   {'source': 'georgia',
#    'target': 'uzbekistan',
#    'weight': 0.044000000000000004},
#   {'source': 'bahrain',
#    'target': 'saudi arabia',
#    'weight': 0.036000000000000004},
#   {'source': 'bahrain', 'target': 'uae', 'weight': 0.024},
#   {'source': 'bahrain', 'target': 'us', 'weight': 0.022000000000000002},
#   {'source': 'jordan', 'target': 'us', 'weight': 0.21},
#   {'source': 'jordan', 'target': 'saudi arabia', 'weight': 0.165},
#   {'source': 'jordan', 'target': 'iraq', 'weight': 0.10300000000000001},
#   {'source': 'jordan', 'target': 'india', 'weight': 0.087},
#   {'source': 'jordan', 'target': 'uae', 'weight': 0.048},
#   {'source': 'jordan', 'target': 'kuwait', 'weight': 0.044000000000000004},
#   {'source': 'kuwait', 'target': 'south korea', 'weight': 0.145},
#   {'source': 'kuwait', 'target': 'china', 'weight': 0.121},
#   {'source': 'kuwait', 'target': 'india', 'weight': 0.121},
#   {'source': 'kuwait', 'target': 'japan', 'weight': 0.10400000000000001},
#   {'source': 'kuwait', 'target': 'us', 'weight': 0.076},
#   {'source': 'kuwait', 'target': 'pakistan', 'weight': 0.059000000000000004},
#   {'source': 'kuwait', 'target': 'singapore', 'weight': 0.043},
#   {'source': 'qatar', 'target': 'japan', 'weight': 0.254},
#   {'source': 'qatar', 'target': 'india', 'weight': 0.146},
#   {'source': 'qatar', 'target': 'china', 'weight': 0.084},
#   {'source': 'qatar', 'target': 'uae', 'weight': 0.068},
#   {'source': 'qatar', 'target': 'singapore', 'weight': 0.055999999999999994},
#   ...],
#  'multigraph': False,
#  'nodes': [{'degree': 8, 'id': 'algeria'},
#   {'degree': 31, 'id': 'spain'},
#   {'degree': 57, 'id': 'france'},
#   {'degree': 103, 'id': 'us'},
#   {'degree': 52, 'id': 'italy'},
#   {'degree': 49, 'id': 'uk'},
#   {'degree': 13, 'id': 'brazil'},
#   {'degree': 6, 'id': 'tunisia'},
#   {'degree': 72, 'id': 'germany'},
#   {'degree': 7, 'id': 'angola'},
#   {'degree': 95, 'id': 'china'},
#   {'degree': 53, 'id': 'india'},
#   {'degree': 18, 'id': 'south africa'},
#   {'degree': 8, 'id': 'benin'},
#   {'degree': 9, 'id': 'gabon'},
#   {'degree': 5, 'id': 'niger'},
#   {'degree': 9, 'id': 'bangladesh'},
#   {'degree': 18, 'id': 'nigeria'},
#   {'degree': 11, 'id': 'vietnam'},
#   {'degree': 9, 'id': 'burundi'},
#   {'degree': 12, 'id': 'pakistan'},
#   {'degree': 6, 'id': 'democratic republic of the congo'},
#   {'degree': 10, 'id': 'uganda'},
#   {'degree': 15, 'id': 'sweden'},
#   {'degree': 26, 'id': 'belgium'},
#   {'degree': 10, 'id': 'rwanda'},
#   {'degree': 4, 'id': 'chad'},
#   {'degree': 44, 'id': 'japan'},
#   {'degree': 5, 'id': 'congo (brazzaville)'},
#   {'degree': 10, 'id': 'portugal'},
#   {'degree': 4, 'id': 'drc'},
#   {'degree': 6, 'id': 'zambia'},
#   {'degree': 26, 'id': 'south korea'},
#   {'degree': 8, 'id': 'cameroon'},
#   {'degree': 41, 'id': 'netherlands'},
#   {'degree': 7, 'id': 'comoros'},
#   {'degree': 15, 'id': 'saudi arabia'},
#   {'degree': 16, 'id': 'singapore'},
#   {'degree': 11, 'id': 'mauritius'},
#   {'degree': 7, 'id': 'none'},
#   {'degree': 13, 'id': 'norway'},
#   {'degree': 2, 'id': 'cabo verde'},
#   {'degree': 16, 'id': 'australia'},
#   {'degree': 4, 'id': 'djibouti'},
#   {'degree': 4, 'id': 'somalia'},
#   {'degree': 8, 'id': 'yemen'},
#   {'degree': 18, 'id': 'uae'},
#   {'degree': 9, 'id': 'egypt'},
#   {'degree': 21, 'id': 'turkey'},
#   {'degree': 9, 'id': 'equatorial guinea'},
#   {'degree': 6, 'id': 'ethiopia'},
#   {'degree': 27, 'id': 'switzerland'},
#   {'degree': 4, 'id': 'the gambia'},
#   {'degree': 12, 'id': 'trinidad and tobago'},
#   {'degree': 7, 'id': 'ghana'},
#   {'degree': 7, 'id': 'guinea'},
#   {'degree': 11, 'id': 'ireland'},
#   {'degree': 9, 'id': 'ukraine'},
#   {'degree': 10, 'id': "cote d'ivoire"},
#   {'degree': 4, 'id': 'burkina faso'},
#   {'degree': 8, 'id': 'kenya'},
#   {'degree': 6, 'id': 'tanzania'},
#   {'degree': 6, 'id': 'liberia'},
#   {'degree': 16, 'id': 'poland'},
#   {'degree': 15, 'id': 'greece'},
#   {'degree': 9, 'id': 'libya'},
#   {'degree': 7, 'id': 'syria'},
#   {'degree': 10, 'id': 'madagascar'},
#   {'degree': 7, 'id': 'malawi'},
#   {'degree': 5, 'id': 'zimbabwe'},
#   {'degree': 26, 'id': 'russia'},
#   {'degree': 7, 'id': 'mali'},
#   {'degree': 19, 'id': 'thailand'},
#   {'degree': 10, 'id': 'indonesia'},
#   {'degree': 5, 'id': 'morocco'},
#   {'degree': 6, 'id': 'mauritania'},
#   {'degree': 4, 'id': 'cote divoire'},
#   {'degree': 6, 'id': 'mozambique'},
#   {'degree': 4, 'id': 'guinea-bissau'},
#   {'degree': 9, 'id': 'togo'},
#   {'degree': 1, 'id': 'swaziland'},
#   {'degree': 11, 'id': 'malaysia'},
#   {'degree': 6, 'id': 'seychelles'},
#   {'degree': 1, 'id': 'namibia'},
#   {'degree': 2, 'id': 'botswana'},
#   {'degree': 7, 'id': 'senegal'},
#   {'degree': 5, 'id': 'sierra leone'},
#   {'degree': 10, 'id': 'romania'},
#   {'degree': 7, 'id': 'oman'},
#   {'degree': 5, 'id': 'sudan'},
#   {'degree': 6, 'id': 'lebanon'},
#   {'degree': 5, 'id': 'sao tome and principe'},
#   {'degree': 3, 'id': 'american samoa'},
#   {'degree': 3, 'id': 'solomon islands'},
#   {'degree': 5, 'id': 'fiji'},
#   {'degree': 4, 'id': 'samoa'},
#   {'degree': 9, 'id': 'tonga'},
#   {'degree': 5, 'id': 'french polynesia'},
#   {'degree': 17, 'id': 'hong kong'},
#   {'degree': 6, 'id': 'new caledonia'},
#   {'degree': 6, 'id': 'niue'},
#   {'degree': 8, 'id': 'united kingdom'},
#   {'degree': 5, 'id': 'united states'},
#   {'degree': 6, 'id': 'vanuatu'},
#   {'degree': 8, 'id': 'venezuela'},
#   {'degree': 4, 'id': 'new zealand'},
#   {'degree': 2, 'id': 'nz'},
#   {'degree': 7, 'id': 'aruba'},
#   {'degree': 8, 'id': 'colombia'},
#   {'degree': 1, 'id': 'netherlands antilles'},
#   {'degree': 6, 'id': 'mexico'},
#   {'degree': 7, 'id': 'panama'},
#   {'degree': 10, 'id': 'barbados'},
#   {'degree': 4, 'id': 'st. lucia'},
#   {'degree': 1, 'id': 'st. vincent and the grenadines'},
#   {'degree': 5, 'id': 'antigua and barbuda'},
#   {'degree': 4, 'id': 'st. kitts and nevis'},
#   {'degree': 6, 'id': 'guyana'},
#   {'degree': 4, 'id': 'the bahamas'},
#   {'degree': 3, 'id': 'dominican republic'},
#   {'degree': 7, 'id': 'belize'},
#   {'degree': 9, 'id': 'jamaica'},
#   {'degree': 9, 'id': 'costa rica'},
#   {'degree': 8, 'id': 'nicaragua'},
#   {'degree': 10, 'id': 'guatemala'},
#   {'degree': 7, 'id': 'cuba'},
#   {'degree': 11, 'id': 'canada'},
#   {'degree': 9, 'id': 'dominica'},
#   {'degree': 4, 'id': 'the dominican'},
#   {'degree': 2, 'id': 'haiti'},
#   {'degree': 8, 'id': 'el salvador'},
#   {'degree': 8, 'id': 'honduras'},
#   {'degree': 8, 'id': 'grenada'},
#   {'degree': 9, 'id': 'iceland'},
#   {'degree': 4, 'id': 'saint kitts and nevis'},
#   {'degree': 7, 'id': 'azerbaijan'},
#   {'degree': 9, 'id': 'saint lucia'},
#   {'degree': 8, 'id': 'suriname'},
#   {'degree': 8, 'id': 'argentina'},
#   {'degree': 8, 'id': 'chile'},
#   {'degree': 8, 'id': 'saint vincent and the grenadines'},
#   {'degree': 7, 'id': 'kyrgyzstan'},
#   {'degree': 8, 'id': 'uzbekistan'},
#   {'degree': 9, 'id': 'kazakhstan'},
#   {'degree': 6, 'id': 'afghanistan'},
#   {'degree': 8, 'id': 'belarus'},
#   {'degree': 9, 'id': 'tajikistan'},
#   {'degree': 7, 'id': 'iran'},
#   {'degree': 2, 'id': 'turkmenistan'},
#   {'degree': 4, 'id': 'burma'},
#   {'degree': 6, 'id': 'brunei'},
#   {'degree': 9, 'id': 'cambodia'},
#   {'degree': 1, 'id': 'north korea'},
#   {'degree': 3, 'id': 'laos'},
#   {'degree': 2, 'id': 'macau'},
#   {'degree': 2, 'id': 'mongolia'},
#   {'degree': 3, 'id': 'papua new guinea'},
#   {'degree': 7, 'id': 'philippines'},
#   {'degree': 5, 'id': 'taiwan'},
#   {'degree': 7, 'id': 'albania'},
#   {'degree': 9, 'id': 'kosovo'},
#   {'degree': 13, 'id': 'austria'},
#   {'degree': 12, 'id': 'slovakia'},
#   {'degree': 8, 'id': 'bosnia and herzegovina'},
#   {'degree': 10, 'id': 'slovenia'},
#   {'degree': 9, 'id': 'croatia'},
#   {'degree': 10, 'id': 'bulgaria'},
#   {'degree': 5, 'id': 'cyprus'},
#   {'degree': 5, 'id': 'israel'},
#   {'degree': 11, 'id': 'denmark'},
#   {'degree': 9, 'id': 'estonia'},
#   {'degree': 9, 'id': 'finland'},
#   {'degree': 10, 'id': 'latvia'},
#   {'degree': 11, 'id': 'lithuania'},
#   {'degree': 6, 'id': 'czechia'},
#   {'degree': 8, 'id': 'faroe islands'},
#   {'degree': 7, 'id': 'serbia'},
#   {'degree': 11, 'id': 'hungary'},
#   {'degree': 4, 'id': 'czech republic'},
#   {'degree': 5, 'id': 'macedonia'},
#   {'degree': 6, 'id': 'luxembourg'},
#   {'degree': 6, 'id': 'moldova'},
#   {'degree': 3, 'id': 'montenegro'},
#   {'degree': 4, 'id': 'monaco'},
#   {'degree': 1, 'id': 'europe'},
#   {'degree': 1, 'id': 'africa'},
#   {'degree': 1, 'id': 'america'},
#   {'degree': 1, 'id': 'asia'},
#   {'degree': 8, 'id': 'malta'},
#   {'degree': 1, 'id': 'san marino'},
#   {'degree': 9, 'id': 'armenia'},
#   {'degree': 11, 'id': 'iraq'},
#   {'degree': 9, 'id': 'georgia'},
#   {'degree': 3, 'id': 'bahrain'},
#   {'degree': 6, 'id': 'jordan'},
#   {'degree': 10, 'id': 'kuwait'},
#   {'degree': 7, 'id': 'qatar'},
#   {'degree': 5, 'id': 'bermuda'},
#   {'degree': 4, 'id': 'greenland'},
#   {'degree': 7, 'id': 'bolivia'},
#   {'degree': 6, 'id': 'ecuador'},
#   {'degree': 5, 'id': 'peru'},
#   {'degree': 4, 'id': 'paraguay'},
#   {'degree': 4, 'id': 'uruguay'},
#   {'degree': 2, 'id': 'bhutan'},
#   {'degree': 5, 'id': 'sri lanka'},
#   {'degree': 8, 'id': 'maldives'},
#   {'degree': 2, 'id': 'nepal'}]}
