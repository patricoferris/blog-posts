# %% [markdown]
# ### Webscraping
# ------------------------

# %%
import requests
from bs4 import BeautifulSoup
import json

result = requests.get('https://github.com/factbook/factbook.json')

content = result.content

bsoup = BeautifulSoup(content, 'html5lib')

tds = bsoup.find_all('td', class_='content')

continents = []
for td in tds[1:14]:
    continents.append(td.text.split('\n')[1].split(' ')[-1])

code_to_continent = {}

for continent in continents: 
    if continent != 'meta':
        url = 'https://github.com/factbook/factbook.json/tree/master/{c}'.format(c=continent)
        countries_page = requests.get(url)
        content = countries_page.content
        bsoup = BeautifulSoup(content, 'html5lib')
        tds = bsoup.find_all('td', class_='content')
        for td in tds[1:]:
            code_to_continent[td.text.split('\n')[1].split(' ')[-1].split('.')[0]] = continent

# %%
class Country:
    def __init__(self, name, code):
        self.name = name.lower()
        self.code = code
        self.exporting_partners = {}
    def add_partner(self, p, v):
        self.exporting_partners[p] = v

# %%
idx = 0

countries = {}

for code in code_to_continent:
    print(code)
    url = 'https://raw.githubusercontent.com/factbook/factbook.json/master/{continent}/{code}.json'.format(continent=code_to_continent[code], code=code)
    print(url)
    json = requests.get(url).json()
    if 'Country name' in json['Government']:
        if 'conventional short form' in json['Government']['Country name']:
            name = json['Government']['Country name']['conventional short form']['text']
            if 'Exports - partners' in json['Economy']:
                partners = json['Economy']['Exports - partners']['text'].split(',')
                print(partners)
                country = Country(name, code)
                for partner in partners:
                    p = partner.split()
                    if p[-1][0] == '(':
                        country.add_partner(' '.join(p[0:-2]).lower(), float(p[-2].split('%')[0]))
                    elif p[-1][0] == 'e':
                        country.add_partner(' '.join(p[0:-3]).lower(), float(p[-3].split('%')[0]))  
                        print(p)
                    else:
                        country.add_partner(' '.join(p[0:-1]).lower(), float(p[-1].split('%')[0]))
                countries[code] = country
# Out:
# ag
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ag.json
# ['Spain 18.8%', ' France 11.2%', ' US 8.8%', ' Italy 8.7%', ' UK 7.1%', ' Brazil 5.2%', ' Tunisia 4.9%', ' Germany 4.5% (2015)']
# ao
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ao.json
# ['China 43.8%', ' India 9.6%', ' US 7.7%', ' Spain 6.2%', ' South Africa 4.8%', ' France 4.4% (2015)']
# bc
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/bc.json
# bn
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/bn.json
# ['India 24.2%', ' Gabon 14.6%', ' China 7.2%', ' Niger 6%', ' Bangladesh 5%', ' Nigeria 4.9%', ' Vietnam 4.2% (2015)']
# by
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/by.json
# ['Germany 12.3%', ' Pakistan 10.7%', ' Democratic Republic of the Congo 10.7%', ' Uganda 8.1%', ' Sweden 7.8%', ' US 7.1%', ' Belgium 6.3%', ' Rwanda 4.6%', ' France 4.4% (2015)']
# cd
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/cd.json
# ['US 58.5%', ' India 13.3%', ' Japan 11.3%', ' China 4.1% (2015)']
# cf
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/cf.json
# ['China 42.1%', ' Italy 16.9%', ' US 4.9%', ' India 4.7%', ' Portugal 4.2% (2015)']
# cg
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/cg.json
# ['China 43.5%', ' Zambia 25%', ' South Korea 4.9%', ' Belgium 4.8% (2015)']
# cm
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/cm.json
# ['China 16.7%', ' India 15.7%', ' Spain 6.2%', ' Belgium 6.1%', ' France 6.1%', ' Portugal 5.6%', ' Netherlands 5%', ' Italy 5% (2015)']
# cn
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/cn.json
# ['India 28.7%', ' France 17%', ' Germany 8.7%', ' Saudi Arabia 7.1%', ' Singapore 6.6%', ' Netherlands 6.1%', ' Mauritius 5.3% (2015)']
# ct
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ct.json
# ['Norway 52.2%', ' China 14.1%', ' Democratic Republic of the Congo 8.3% (2015)']
# cv
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/cv.json
# ['Australia 83%', ' Spain 8.6% (2015)']
# dj
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/dj.json
# ['Somalia 79.8%', ' US 5.4%', ' Yemen 4.6%', ' UAE 4% (2015)']
# eg
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/eg.json
# ['Saudi Arabia 9.1%', ' Italy 7.5%', ' Turkey 5.8%', ' UAE 5.1%', ' US 5.1%', ' UK 4.4%', ' India 4.1% (2015)']
# ek
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ek.json
# ['China 16.6%', ' South Korea 15.1%', ' Spain 9%', ' Brazil 8.2%', ' Netherlands 6.8%', ' South Africa 6.6%', ' India 5.8%', ' UK 5.7%', ' France 5.7% (2015)']
# er
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/er.json
# et
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/et.json
# ['Switzerland 14.3%', ' China 11.7%', ' US 9.5%', ' Netherlands 8.8%', ' Saudi Arabia 5.9%', ' Germany 5.7% (2015)']
# ga
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ga.json
# ['China 47.6%', ' India 27.2%', ' France 5.9%', ' UK 4.9% (2015)']
# gb
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/gb.json
# ['China 15.5%', ' Italy 7.3%', ' Trinidad and Tobago 7.2%', ' Australia 7%', ' Spain 6.3%', ' South Korea 5.4%', ' Netherlands 5%', ' US 4.7% (2015)']
# gh
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/gh.json
# ['India 25.2%', ' Switzerland 12.2%', ' China 10.6%', ' France 5.7% (2015)']
# gv
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/gv.json
# ['India 22.5%', ' Spain 8.2%', ' Ireland 7.3%', ' Germany 6.2%', ' Belgium 5.5%', ' Ukraine 5.3%', ' France 4.1% (2015)']
# iv
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/iv.json
# ['US 8.5%', ' Netherlands 6.2%', ' France 5.6%', ' Germany 5.6%', ' Nigeria 5.5%', ' Burkina Faso 5.5%', ' Belgium 5.3%', ' India 4.6%', ' Ghana 4.4%', ' Switzerland 4.1% (2015)']
# ke
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ke.json
# ['Uganda 11.2%', ' US 8.3%', ' Tanzania 8.1%', ' Netherlands 7.4%', ' UK 6%', ' Pakistan 4.2% (2015)']
# li
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/li.json
# ['Poland 32.9%', ' China 20.7%', ' India 9.3%', ' US 5.1%', ' Greece 4.7%', ' France 4.3% (2015)']
# lt
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/lt.json
# ly
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ly.json
# ['Italy 32.1%', ' Germany 11.3%', ' China 8%', ' France 8%', ' Spain 5.6%', ' Netherlands 5.4%', ' Syria 5.3% (2015)']
# ma
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ma.json
# ['France 15.2%', ' US 12.7%', ' China 7.1%', ' South Africa 5.9%', ' Japan 5.5%', ' Netherlands 5.4%', ' Germany 5.1%', ' Belgium 5%', ' India 4.4% (2015)']
# mi
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/mi.json
# ['Belgium 15.8%', ' Zimbabwe 12%', ' India 6.9%', ' South Africa 6.2%', ' US 6%', ' Russia 5.6%', ' Germany 4.6% (2015)']
# ml
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ml.json
# ['Switzerland 48.5%', ' China 9.4%', ' India 9.1%', ' Bangladesh 8%', ' Thailand 4.5%', ' Indonesia 4.4% (2015)']
# mo
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/mo.json
# ['Spain 22.1%', ' France 19.7%', ' India 4.9%', ' US 4.3%', ' Italy 4.3% (2015)']
# mp
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/mp.json
# ['UK 13.2%', ' UAE 12.4%', ' France 11.9%', ' US 10.7%', ' South Africa 8.6%', ' Madagascar 6.5%', ' Italy 5.4%', ' Spain 4.4% (2015)']
# mr
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/mr.json
# ['China 32.7%', ' Switzerland 11.1%', ' Spain 8.6%', ' Italy 6.7%', ' Cote dIvoire 6.6%', ' Japan 5.7% (2015)']
# mz
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/mz.json
# ['South Africa 24.9%', ' China 10.2%', ' Italy 8.9%', ' India 8.9%', ' Belgium 7.9%', ' Spain 4.4% (2015)']
# ng
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ng.json
# ['France 53.1%', ' Nigeria 20.3%', ' China 13.8% (2015)']
# ni
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ni.json
# ['India 18.2%', ' Netherlands 8.5%', ' Spain 8.2%', ' Brazil 8.2%', ' South Africa 7.8%', ' France 5.2%', ' Japan 4.5%', ' Cote dIvoire 4.2%', ' Ghana 4% (2015)']
# od
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/od.json
# pu
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/pu.json
# ['India 63.5%', ' Nigeria 20.3%', ' China 5.7%', ' Togo 5.6% (2015)']
# rw
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/rw.json
# ['Democratic Republic of the Congo 19.8%', ' US 10.8%', ' China 10.3%', ' Swaziland 7.9%', ' Malaysia 7%', ' Pakistan 6.2%', ' Germany 5.9%', ' Thailand 5.5% (2015)']
# se
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/se.json
# ['France 18.2%', ' UK 17.9%', ' Mauritius 10%', ' Japan 9.2%', ' Italy 7.8%', ' Spain 4.5% (2015)']
# sf
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/sf.json
# ['China 11.3%', ' US 7.3%', ' Germany 6%', ' Namibia 5.2%', ' Botswana 5.2%', ' Japan 4.7%', ' UK 4.3%', ' India 4.2% (2015)']
# sg
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/sg.json
# ['Mali 12.8%', ' Switzerland 9.7%', ' India 5.9%', ' Cote dIvoire 5.3%', ' China 5.1%', ' UAE 4.1%', ' France 4.1% (2015)']
# sh
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/sh.json
# sl
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/sl.json
# ['China 31.3%', ' Belgium 27.8%', ' Romania 11.3%', ' US 7.3%', ' India 4% (2015)']
# so
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/so.json
# ['UAE 45.8%', ' Yemen 19.7%', ' Oman 15.9% (2015)']
# su
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/su.json
# ['UAE 32%', ' China 16.2%', ' Saudi Arabia 15.5%', ' Australia 4.7%', ' India 4.2% (2015)']
# to
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/to.json
# ['India 14.6%', ' Burkina Faso 11.3%', ' China 11.3%', ' Benin 9.6%', ' Ghana 9%', ' Lebanon 8.3%', ' Nigeria 6.1%', ' Niger 5.9% (2015)']
# tp
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/tp.json
# ['Netherlands 29.2%', ' Belgium 22.4%', ' Spain 15.5%', ' US 6.6%', ' Nigeria 5.1% (2015)']
# ts
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ts.json
# ['France 28.5%', ' Italy 17.2%', ' Germany 10.9%', ' Libya 6.1%', ' Spain 4.2% (2015)']
# tz
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/tz.json
# ['India 21.4%', ' China 8.1%', ' Japan 5.1%', ' Kenya 4.6%', ' Belgium 4.3% (2015)']
# ug
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/ug.json
# ['Rwanda 10.7%', ' UAE 9.9%', ' Democratic Republic of the Congo 9.8%', ' Kenya 9.7%', ' Italy 5.8%', ' Netherlands 4.8%', ' Germany 4.7%', ' China 4.1% (2015)']
# uv
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/uv.json
# ['Switzerland 53.3%', ' India 14.5% (2015)']
# wa
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/wa.json
# wi
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/wi.json
# wz
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/wz.json
# za
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/za.json
# ['China 25.5%', ' Democratic Republic of the Congo 13%', ' South Africa 6.4%', ' South Korea 4.9%', ' India 4.3% (2015)']
# zi
# https://raw.githubusercontent.com/factbook/factbook.json/master/africa/zi.json
# ['China 27.8%', ' Democratic Republic of the Congo 14%', ' Botswana 12.5%', ' South Africa 7.6% (2015)']
# ay
# https://raw.githubusercontent.com/factbook/factbook.json/master/antarctica/ay.json
# bv
# https://raw.githubusercontent.com/factbook/factbook.json/master/antarctica/bv.json
# fs
# https://raw.githubusercontent.com/factbook/factbook.json/master/antarctica/fs.json
# hm
# https://raw.githubusercontent.com/factbook/factbook.json/master/antarctica/hm.json
# aq
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/aq.json
# ['US 100%']
# as
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/as.json
# ['China 32.2%', ' Japan 15.9%', ' South Korea 7.1%', ' US 5.4%', ' India 4.2% (2015)']
# at
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/at.json
# bp
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/bp.json
# ['China 61.7%', ' India 5.9%', ' Italy 5.9% (2015)']
# ck
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/ck.json
# cq
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/cq.json
# cr
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/cr.json
# cw
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/cw.json
# fj
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/fj.json
# ['US 13.4%', ' Australia 10.2%', ' Samoa 6.7%', ' Tonga 5.9% (2015)']
# fm
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/fm.json
# fp
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/fp.json
# ['Japan 35%', ' US 24%', ' Hong Kong 17%', ' France 9.1%', ' China 4.2% (2014)']
# gq
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/gq.json
# kr
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/kr.json
# kt
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/kt.json
# nc
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/nc.json
# ['China 31.8%', ' Japan 15.2%', ' South Korea 10.7%', ' Australia 8.1%', ' France 7.4%', ' Belgium 5.1% (2015)']
# ne
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/ne.json
# ['Germany 25%', ' Belgium 11%', ' United Kingdom 8%', ' France 8%', ' Italy 4%', ' United States 4% (2014)']
# nf
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/nf.json
# nh
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/nh.json
# ['Japan 35.1%', ' Turkey 10.5%', ' Thailand 8.7%', ' China 8.2%', ' Venezuela 5.9%', ' UK 5.6% (2015)']
# nr
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/nr.json
# nz
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/nz.json
# ['China 17.5%', ' Australia 16.9%', ' US 11.8%', ' Japan 6% (2015)']
# pc
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/pc.json
# ps
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/ps.json
# rm
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/rm.json
# tl
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/tl.json
# tn
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/tn.json
# ['Japan 16%', ' US 15.4%', ' Fiji 12.8%', ' NZ 12.5%', ' South Korea 11%', ' Samoa 10.7%', ' Australia 7.5%', ' American Samoa 6.8% (2015)']
# tv
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/tv.json
# um
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/um.json
# wf
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/wf.json
# wq
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/wq.json
# ws
# https://raw.githubusercontent.com/factbook/factbook.json/master/australia-oceania/ws.json
# ['American Samoa 57.1%', ' Australia 17.2% (2015)']
# aa
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/aa.json
# ['Colombia 28.2%', ' Netherlands Antilles 18.1%', ' US 14.3%', ' Netherlands 10.1%', ' Mexico 6.5%', ' Venezuela 6.3%', ' Panama 4.1% (2015)']
# ac
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/ac.json
# av
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/av.json
# bb
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/bb.json
# ['Trinidad and Tobago 22.5%', ' US 11.8%', ' St. Lucia 9.2%', ' St. Vincent and the Grenadines 5.7%', ' Antigua and Barbuda 4.7%', ' St. Kitts and Nevis 4.4%', ' Guyana 4.2% (2015)']
# bf
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/bf.json
# ['Poland 26.3%', ' Cote dIvoire 20.9%', ' US 15.9%', ' Dominican Republic 14.3% (2015)']
# bh
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/bh.json
# ['UK 30.8%', ' US 18.7%', ' Nigeria 6.7%', ' Trinidad and Tobago 4.8%', ' Ireland 4.2%', ' Jamaica 4.2% (2015)']
# bq
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/bq.json
# cc
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/cc.json
# cj
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/cj.json
# cs
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/cs.json
# ['US 33.6%', ' China 6.2%', ' Mexico 4.6%', ' Nicaragua 4.3%', ' Netherlands 4.2%', ' Guatemala 4% (2015)']
# cu
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/cu.json
# ['Canada 17.7%', ' Venezuela 13.8%', ' China 13%', ' Netherlands 6.4%', ' Spain 5.4%', ' Belize 4.7% (2015)']
# do
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/do.json
# ['Japan 38.1%', ' Jamaica 19%', ' Antigua and Barbuda 10.4%', ' Trinidad and Tobago 6.2%', ' St. Lucia 4.8%', ' St. Kitts and Nevis 4.2% (2015)']
# dr
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/dr.json
# ['US 42.5%', ' Haiti 16.5%', ' Canada 8.1%', ' India 4.8% (2015)']
# es
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/es.json
# ['US 47.1%', ' Honduras 13.9%', ' Guatemala 13.6%', ' Nicaragua 6.6%', ' Costa Rica 4.5% (2015)']
# gj
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/gj.json
# ['Nigeria 44.7%', ' St. Lucia 10.8%', ' Antigua and Barbuda 7.3%', ' St. Kitts and Nevis 6.6%', ' Dominica 6.6%', ' US 5.8% (2015)']
# gt
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/gt.json
# ['US 34.9%', ' El Salvador 8.4%', ' Honduras 7.3%', ' Nicaragua 5%', ' Canada 4.6%', ' Mexico 4.3%', ' Costa Rica 4.1% (2015)']
# ha
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/ha.json
# ['US 85.3% (2015)']
# ho
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/ho.json
# ['US 36%', ' Germany 8.7%', ' El Salvador 8.5%', ' Guatemala 6%', ' Nicaragua 5.6%', ' Netherlands 4.1% (2015)']
# jm
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/jm.json
# ['US 24.4%', ' Canada 16.5%', ' Russia 9.3%', ' Netherlands 8.9%', ' Iceland 7.2%', ' UK 6.5% (2015)']
# mh
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/mh.json
# nu
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/nu.json
# ['US 56.5%', ' Mexico 10.7%', ' Venezuela 5.4%', ' El Salvador 4.3% (2015)']
# pm
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/pm.json
# ['US 19.7%', ' Germany 13.2%', ' Costa Rica 7.7%', ' China 5.9%', ' Netherlands 4.1% (2015)']
# rn
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/rn.json
# rq
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/rq.json
# sc
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/sc.json
# ['US 44.4%', ' Poland 14.6%', ' Bangladesh 10.1%', ' Azerbaijan 4.3% (2015)']
# sk
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/sk.json
# st
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/st.json
# ['Dominican Republic 25.1%', ' US 15.9%', ' Suriname 9.1%', ' Antigua and Barbuda 7%', ' Dominica 6.8%', ' Trinidad and Tobago 6.3%', ' Barbados 6.1%', ' UK 4.8%', ' Grenada 4.6% (2015)']
# tb
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/tb.json
# td
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/td.json
# ['US 26.3%', ' Argentina 12%', ' Brazil 6.6%', ' Chile 5.3%', ' Dominican Republic 5.2%', ' Barbados 5% (2015)']
# tk
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/tk.json
# vc
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/vc.json
# ['Trinidad and Tobago 18.9%', ' St. Lucia 14.8%', ' Barbados 12.3%', ' Dominica 9.7%', ' Grenada 9.3%', ' Antigua and Barbuda 8.4%', ' Poland 7.1%', ' St. Kitts and Nevis 4.1% (2015)']
# vi
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/vi.json
# vq
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-america-n-caribbean/vq.json
# kg
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-asia/kg.json
# ['Switzerland 26%', ' Uzbekistan 22.6%', ' Kazakhstan 20.8%', ' UAE 4.9%', ' Turkey 4.5%', ' Afghanistan 4.5%', ' Russia 4.2% (2015)']
# kz
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-asia/kz.json
# ['China 15.1%', ' Russia 12.3%', ' France 9.2%', ' Germany 7.9%', ' Italy 6.7%', ' Greece 4.1% (2015)']
# rs
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-asia/rs.json
# ['Netherlands 11.9%', ' China 8.3%', ' Germany 7.4%', ' Italy 6.5%', ' Turkey 5.6%', ' Belarus 4.4%', ' Japan 4.2% (2015)']
# ti
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-asia/ti.json
# ['Turkey 19.7%', ' Kazakhstan 17.6%', ' Switzerland 13.7%', ' Iran 8.7%', ' Afghanistan 7.5%', ' Russia 5.1%', ' China 4.9%', ' Italy 4.8% (2015)']
# tx
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-asia/tx.json
# ['China 68.6%', ' Turkey 4.9% (2015)']
# uz
# https://raw.githubusercontent.com/factbook/factbook.json/master/central-asia/uz.json
# ['Switzerland 25.8%', ' China 17.6%', ' Kazakhstan 14.2%', ' Turkey 9.9%', ' Russia 8.4%', ' Bangladesh 6.9% (2015)']
# bm
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/bm.json
# ['China 37.7%', ' Thailand 25.6%', ' India 7.7%', ' Japan 6.2% (2015)']
# bx
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/bx.json
# ['Japan 35.9%', ' South Korea 14.8%', ' Thailand 10.8%', ' India 9.8%', ' NZ 5.6%', ' Australia 5% (2015)']
# cb
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/cb.json
# ['US 23.1%', ' UK 8.8%', ' Germany 8.2%', ' Japan 7.4%', ' Canada 6.7%', ' China 5.1%', ' Vietnam 5%', ' Thailand 4.9%', ' Netherlands 4.1% (2015)']
# ch
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/ch.json
# ['US 18%', ' Hong Kong 14.6%', ' Japan 6%', ' South Korea 4.5% (2015)']
# hk
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/hk.json
# ['China 53.7%', ' US 9.5% (2015)']
# id
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/id.json
# ['Japan 12%', ' US 10.8%', ' China 10%', ' Singapore 8.4%', ' India 7.8%', ' South Korea 5.1%', ' Malaysia 5.1% (2015)']
# ja
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/ja.json
# ['US 20.2%', ' China 17.5%', ' South Korea 7.1%', ' Hong Kong 5.6%', ' Thailand 4.5% (2015)']
# kn
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/kn.json
# ['China 75.8% (2015)']
# ks
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/ks.json
# ['China 26%', ' US 13.3%', ' Hong Kong 5.8%', ' Vietnam 5.3%', ' Japan 4.9% (2015)']
# la
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/la.json
# ['Thailand 30.4%', ' China 27%', ' Vietnam 17.6% (2015)']
# mc
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/mc.json
# ['Hong Kong 63.4%', ' China 18.2% (2015)']
# mg
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/mg.json
# ['China 84%', ' Switzerland 9% (2015)']
# my
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/my.json
# ['Singapore 13.9%', ' China 13%', ' Japan 9.5%', ' US 9.4%', ' Thailand 5.7%', ' Hong Kong 4.7%', ' India 4.1% (2015)']
# pf
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/pf.json
# pg
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/pg.json
# pp
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/pp.json
# ['Japan 17.4%', ' Australia 15.9%', ' China 12.1% (2015)']
# rp
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/rp.json
# ['Japan 21.1%', ' US 15%', ' China 10.9%', ' Hong Kong 10.6%', ' Singapore 6.2%', ' Germany 4.5%', ' South Korea 4.3% (2015)']
# sn
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/sn.json
# ['China 13.7%', ' Hong Kong 11.5%', ' Malaysia 10.8%', ' Indonesia 8.2%', ' US 6.9%', ' Japan 4.4%', ' South Korea 4.1% (2015)']
# th
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/th.json
# ['US 11.2%', ' China 11.1%', ' Japan 9.4%', ' Hong Kong 5.5%', ' Malaysia 4.8%', ' Australia 4.6%', ' Vietnam 4.2%', ' Singapore 4.1% (2015)']
# tt
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/tt.json
# tw
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/tw.json
# ['China 27.1%', ' Hong Kong 13.2%', ' US 10.3%', ' Japan 6.4%', ' Singapore 4.4% (2012 est.)']
# ['Singapore', '4.4%', '(2012', 'est.)']
# vm
# https://raw.githubusercontent.com/factbook/factbook.json/master/east-n-southeast-asia/vm.json
# ['US 21.2%', ' China 13.3%', ' Japan 8.4%', ' South Korea 5.5%', ' Germany 4.1% (2015)']
# al
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/al.json
# ['Italy 43.4%', ' Kosovo 9.8%', ' US 7.7%', ' China 6.2%', ' Greece 5.3%', ' Spain 4.8% (2015)']
# an
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/an.json
# au
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/au.json
# ['Germany 29.4%', ' US 6.4%', ' Italy 6.1%', ' Switzerland 5.7%', ' France 4.4%', ' Slovakia 4.2% (2015)']
# ax
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ax.json
# be
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/be.json
# ['Germany 16.9%', ' France 15.5%', ' Netherlands 11.4%', ' UK 8.8%', ' US 6%', ' Italy 5% (2015)']
# bk
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/bk.json
# ['Slovenia 16.5%', ' Italy 15.9%', ' Germany 12.1%', ' Croatia 11.5%', ' Austria 11.1%', ' Turkey 5.2% (2015)']
# bo
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/bo.json
# ['Russia 39%', ' UK 11.2%', ' Ukraine 9.5%', ' Netherlands 4.3%', ' Germany 4.1% (2015)']
# bu
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/bu.json
# ['Germany 12.5%', ' Italy 9.2%', ' Turkey 8.5%', ' Romania 8.2%', ' Greece 6.5%', ' France 4.2% (2015)']
# cy
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/cy.json
# ['Greece 10.9%', ' Ireland 10.2%', ' UK 7.2%', ' Israel 6% (2015)']
# da
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/da.json
# ['Germany 17.8%', ' Sweden 11.6%', ' US 8.4%', ' Norway 6.3%', ' UK 6.3%', ' Netherlands 4.4%', ' China 4.2% (2015)']
# dx
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/dx.json
# ee
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ee.json
# ei
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ei.json
# ['US 23.7%', ' UK 13.8%', ' Belgium 13.2%', ' Germany 6.6%', ' Switzerland 5.5%', ' Netherlands 4.4%', ' France 4.4% (2015)']
# en
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/en.json
# ['Sweden 18.8%', ' Finland 16%', ' Latvia 10.4%', ' Russia 6.7%', ' Lithuania 5.9%', ' Germany 5.2%', ' Norway 4.1% (2015)']
# ez
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ez.json
# ['Germany 32.4%', ' Slovakia 9%', ' Poland 5.8%', ' UK 5.3%', ' France 5.1%', ' Austria 4.1% (2015)']
# fi
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/fi.json
# ['Germany 13.9%', ' Sweden 10.1%', ' US 7%', ' Netherlands 6.6%', ' Russia 5.9%', ' UK 5.2%', ' China 4.7% (2015)']
# fo
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/fo.json
# ['Russia 20.2%', ' UK 16.6%', ' Denmark 16.3%', ' Nigeria 11.6%', ' China 9.3%', ' US 7.2%', ' Netherlands 5.6%', ' Norway 4% (2015)']
# fr
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/fr.json
# ['Germany 15.9%', ' Spain 7.3%', ' US 7.2%', ' Italy 7.1%', ' UK 7.1%', ' Belgium 6.8% (2015)']
# gi
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/gi.json
# gk
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/gk.json
# gm
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/gm.json
# ['US 9.6%', ' France 8.6%', ' UK 7.5%', ' Netherlands 6.6%', ' China 6%', ' Italy 4.9%', ' Austria 4.8%', ' Poland 4.4%', ' Switzerland 4.2% (2015)']
# gr
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/gr.json
# ['Italy 11.2%', ' Germany 7.3%', ' Turkey 6.6%', ' Cyprus 5.9%', ' Bulgaria 5.2%', ' US 4.8%', ' UK 4.2%', ' Egypt 4% (2015)']
# hr
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/hr.json
# ['Italy 13.4%', ' Slovenia 12.5%', ' Germany 11.4%', ' Bosnia and Herzegovina 9.9%', ' Austria 6.6%', ' Serbia 4.9% (2015)']
# hu
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/hu.json
# ['Germany 28%', ' Romania 5.4%', ' Slovakia 5.1%', ' Austria 5%', ' Italy 4.8%', ' France 4.7%', ' UK 4%', ' Czech Republic 4% (2015)']
# ic
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ic.json
# ['Netherlands 26.1%', ' UK 11.6%', ' Spain 11.5%', ' Germany 7.4%', ' France 5.7%', ' US 5.7%', ' Norway 4.7% (2015)']
# im
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/im.json
# it
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/it.json
# ['Germany 12.3%', ' France 10.3%', ' US 8.7%', ' UK 5.4%', ' Spain 4.8%', ' Switzerland 4.7% (2015)']
# je
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/je.json
# jn
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/jn.json
# kv
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/kv.json
# ['Italy 25.8%', ' Albania 14.6%', ' Macedonia 9.6%', ' China 5.5%', ' Germany 5.4%', ' Switzerland 5.4%', ' Turkey 4.1% (2012 est.)']
# ['Turkey', '4.1%', '(2012', 'est.)']
# lg
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/lg.json
# ['Lithuania 17.8%', ' Russia 11.5%', ' Estonia 11.1%', ' Germany 6.3%', ' Poland 5.6%', ' Sweden 5.2%', ' UK 5%', ' Denmark 4% (2015)']
# lh
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/lh.json
# ['Russia 13.7%', ' Latvia 9.8%', ' Poland 9.7%', ' Germany 7.8%', ' Estonia 5.3%', ' Belarus 4.6%', ' UK 4.5%', ' US 4.4%', ' Netherlands 4% (2015)']
# lo
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/lo.json
# ['Germany 22.7%', ' Czech Republic 12.5%', ' Poland 8.5%', ' Austria 5.7%', ' Hungary 5.7%', ' France 5.6%', ' UK 5.5%', ' Italy 4.5% (2015)']
# ls
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ls.json
# lu
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/lu.json
# ['Germany 22.1%', ' Belgium 16.7%', ' France 16.6%', ' UK 4.7%', ' Italy 4.6%', ' Netherlands 4% (2015)']
# md
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/md.json
# ['Romania 23.1%', ' Italy 10.2%', ' Turkey 9.4%', ' Russia 8%', ' Germany 6.6%', ' Belarus 6.4% (2015)']
# mj
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/mj.json
# ['Croatia 22.7%', ' Serbia 22.7%', ' Slovenia 7.8% (2012 est.)']
# ['Slovenia', '7.8%', '(2012', 'est.)']
# mk
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/mk.json
# ['Germany 33.2%', ' Kosovo 11.5%', ' Bulgaria 5.1%', ' Greece 4.5% (2015)']
# mn
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/mn.json
# ['Europe 73.2%', ' Africa 14.6%', ' America 5.2%', ' Asia 4.9% (2013 est.)']
# ['Asia', '4.9%', '(2013', 'est.)']
# mt
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/mt.json
# ['Germany 13.3%', ' France 10.2%', ' Hong Kong 7.4%', ' Singapore 7.3%', ' UK 6.4%', ' US 5.8%', ' Italy 5.6%', ' Japan 4.7% (2015)']
# nl
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/nl.json
# ['Germany 24.5%', ' Belgium 11.1%', ' UK 9.3%', ' France 8.4%', ' Italy 4.2% (2015)']
# no
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/no.json
# ['UK 22.2%', ' Germany 17.9%', ' Netherlands 10.2%', ' France 6.6%', ' Sweden 6.1%', ' Belgium 5%', ' US 4.5% (2015)']
# pl
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/pl.json
# ['Germany 27.1%', ' UK 6.8%', ' Czech Republic 6.6%', ' France 5.5%', ' Italy 4.8%', ' Netherlands 4.4% (2015)']
# po
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/po.json
# ['Spain 25%', ' France 12.1%', ' Germany 11.8%', ' UK 6.7%', ' US 5.2%', ' Angola 4.2%', ' Netherlands 4% (2015)']
# ri
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ri.json
# ['Italy 16.2%', ' Germany 12.6%', ' Bosnia and Herzegovina 8.7%', ' Romania 5.6%', ' Russia 5.4% (2015)']
# ro
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/ro.json
# ['Germany 19.8%', ' Italy 12.5%', ' France 6.8%', ' Hungary 5.4%', ' UK 4.4% (2015)']
# si
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/si.json
# ['Germany 19.1%', ' Italy 10.6%', ' Austria 8%', ' Croatia 6.8%', ' Slovakia 4.7%', ' Hungary 4.4%', ' France 4.2% (2015)']
# sm
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/sm.json
# ['Italy 82.3% (2012 est.)']
# ['Italy', '82.3%', '(2012', 'est.)']
# sp
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/sp.json
# ['France 15.7%', ' Germany 11%', ' Italy 7.4%', ' UK 7.4%', ' Portugal 7.1%', ' US 4.5% (2015)']
# sv
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/sv.json
# sw
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/sw.json
# ['Norway 10.3%', ' Germany 10.3%', ' US 7.7%', ' UK 7.2%', ' Denmark 6.8%', ' Finland 6.7%', ' Netherlands 5.2%', ' Belgium 4.4%', ' France 4.2% (2015)']
# sz
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/sz.json
# ['Germany 14.2%', ' US 10.6%', ' Hong Kong 8.7%', ' India 7.3%', ' China 6.9%', ' France 6.1%', ' Italy 5.4%', ' UK 4.8% (2015)']
# uk
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/uk.json
# ['US 14.6%', ' Germany 10.1%', ' Switzerland 7%', ' China 6%', ' France 5.9%', ' Netherlands 5.8%', ' Ireland 5.5% (2015)']
# up
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/up.json
# ['Russia 12.7%', ' Turkey 7.3%', ' China 6.3%', ' Egypt 5.5%', ' Italy 5.2%', ' Poland 5.2% (2015)']
# vt
# https://raw.githubusercontent.com/factbook/factbook.json/master/europe/vt.json
# ae
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/ae.json
# ['Iran 14.5%', ' Japan 9.8%', ' India 9.2%', ' China 4.7%', ' Oman 4.3% (2015)']
# aj
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/aj.json
# ['Italy 26.3%', ' Germany 13.3%', ' Indonesia 7%', ' France 6.9%', ' Czech Republic 6% (2015)']
# am
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/am.json
# ['Russia 15.2%', ' China 11.1%', ' Germany 9.8%', ' Iraq 8.8%', ' Georgia 7.8%', ' Canada 7.6%', ' Bulgaria 5.3%', ' Iran 5.3% (2015)']
# ba
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/ba.json
# ['Saudi Arabia 3.6%', ' UAE 2.4%', ' US 2.2% (2015)']
# gg
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/gg.json
# ['Azerbaijan 10.9%', ' Bulgaria 9.7%', ' Turkey 8.4%', ' Armenia 8.2%', ' Russia 7.4%', ' China 5.7%', ' US 4.7%', ' Uzbekistan 4.4% (2015)']
# gz
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/gz.json
# ir
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/ir.json
# ['China 22.2%', ' India 9.9%', ' Turkey 8.4%', ' Japan 4.5% (2015)']
# is
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/is.json
# ['US 27.5%', ' Hong Kong 8%', ' UK 6.1%', ' China 4.9% (2015)']
# iz
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/iz.json
# ['China 22.6%', ' India 21.1%', ' South Korea 11.2%', ' US 7.8%', ' Italy 6.7%', ' Greece 6% (2015)']
# jo
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/jo.json
# ['US 21%', ' Saudi Arabia 16.5%', ' Iraq 10.3%', ' India 8.7%', ' UAE 4.8%', ' Kuwait 4.4% (2015)']
# ku
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/ku.json
# ['South Korea 14.5%', ' China 12.1%', ' India 12.1%', ' Japan 10.4%', ' US 7.6%', ' Pakistan 5.9%', ' Singapore 4.3% (2015)']
# le
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/le.json
# ['Saudi Arabia 12.1%', ' UAE 10.6%', ' Iraq 7.6%', ' Syria 7.1%', ' South Africa 6.6% (2015)']
# mu
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/mu.json
# ['China 35.4%', ' UAE 15.3%', ' South Korea 6.8%', ' Saudi Arabia 5.8%', ' Pakistan 4.2% (2015)']
# qa
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/qa.json
# ['Japan 25.4%', ' India 14.6%', ' China 8.4%', ' UAE 6.8%', ' Singapore 5.6%', ' UK 5.5%', ' Thailand 4.2% (2015)']
# sa
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/sa.json
# ['China 13.2%', ' Japan 10.9%', ' US 9.6%', ' India 9.6%', ' South Korea 8.5% (2015)']
# sy
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/sy.json
# ['Iraq 64.7%', ' Saudi Arabia 11.2%', ' Kuwait 7.1%', ' UAE 6.1%', ' Libya 4.6% (2015)']
# tu
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/tu.json
# ['Germany 9.3%', ' UK 7.3%', ' Iraq 5.9%', ' Italy 4.8%', ' US 4.5%', ' France 4.1% (2015)']
# we
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/we.json
# ym
# https://raw.githubusercontent.com/factbook/factbook.json/master/middle-east/ym.json
# ['China 24.5%', ' UAE 16.5%', ' South Korea 10%', ' Saudi Arabia 10%', ' Kuwait 9.1%', ' India 8.5% (2015)']
# bd
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/bd.json
# ['US 14.4%', ' Iceland 13.7%', ' Spain 6.8%', ' UK 5.8%', ' Mauritius 5.6% (2015)']
# ca
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/ca.json
# ['US 76.7% (2015)']
# gl
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/gl.json
# ['Denmark 51.6%', ' China 11.1%', ' Japan 9.1%', ' Russia 7.2% (2015)']
# ip
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/ip.json
# mx
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/mx.json
# ['US 81.1% (2015)']
# sb
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/sb.json
# us
# https://raw.githubusercontent.com/factbook/factbook.json/master/north-america/us.json
# ['Canada 18.6%', ' Mexico 15.7%', ' China 7.7%', ' Japan 4.2% (2015)']
# oo
# https://raw.githubusercontent.com/factbook/factbook.json/master/oceans/oo.json
# xo
# https://raw.githubusercontent.com/factbook/factbook.json/master/oceans/xo.json
# xq
# https://raw.githubusercontent.com/factbook/factbook.json/master/oceans/xq.json
# zh
# https://raw.githubusercontent.com/factbook/factbook.json/master/oceans/zh.json
# zn
# https://raw.githubusercontent.com/factbook/factbook.json/master/oceans/zn.json
# ar
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/ar.json
# ['Brazil 17%', ' China 8.6%', ' US 5.9% (2015)']
# bl
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/bl.json
# ['Brazil 28.1%', ' Argentina 16.9%', ' US 12.1%', ' Colombia 6.3%', ' China 5.3%', ' Japan 4.7%', ' South Korea 4.3% (2015)']
# br
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/br.json
# ['China 18.6%', ' US 12.7%', ' Argentina 6.7%', ' Netherlands 5.3% (2015)']
# ci
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/ci.json
# ['China 26.3%', ' US 13.2%', ' Japan 8.5%', ' South Korea 6.5%', ' Brazil 4.9% (2015)']
# co
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/co.json
# ['US 27.5%', ' Panama 7.2%', ' China 5.2%', ' Spain 4.4%', ' Ecuador 4% (2015)']
# ec
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/ec.json
# ['US 39.5%', ' Chile 6.2%', ' Peru 5.1%', ' Vietnam 4.3%', ' Colombia 4.3% (2015)']
# fk
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/fk.json
# gy
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/gy.json
# ['US 33.5%', ' Canada 17.9%', ' UK 6.7%', ' Ukraine 4.3%', ' Jamaica 4% (2015)']
# ns
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/ns.json
# ['Switzerland 21.8%', ' UAE 14.5%', ' India 13.9%', ' Belgium 9.7%', ' US 8.9%', ' France 8.1%', ' Canada 6.6% (2015)']
# pa
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/pa.json
# ['Brazil 31.7%', ' Russia 9.1%', ' Chile 7.1%', ' Argentina 7% (2015)']
# pe
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/pe.json
# ['China 22.1%', ' US 15.2%', ' Switzerland 8.1%', ' Canada 7% (2015)']
# sx
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/sx.json
# uy
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/uy.json
# ['China 15%', ' Brazil 14.4%', ' US 6.5%', ' Argentina 4.9% (2015)']
# ve
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-america/ve.json
# ['US 26.6%', ' India 13.7%', ' China 11.7%', ' Cuba 6.4% (2015)']
# af
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/af.json
# ['India 42.3%', ' Pakistan 29%', ' Tajikistan 7.6% (2015)']
# bg
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/bg.json
# ['US 13.9%', ' Germany 12.9%', ' UK 8.9%', ' France 5%', ' Spain 4.7% (2015)']
# bt
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/bt.json
# ['India 83.8%', ' Hong Kong 10.8% (2013 est.)']
# ['Hong', 'Kong', '10.8%', '(2013', 'est.)']
# ce
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/ce.json
# ['US 26%', ' UK 9%', ' India 7.2%', ' Germany 4.3% (2015)']
# in
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/in.json
# ['US 15.2%', ' UAE 11.4%', ' Hong Kong 4.6% (2015)']
# io
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/io.json
# mv
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/mv.json
# ['Thailand 18%', ' France 12.1%', ' Germany 10.7%', ' US 9.6%', ' Italy 6.8%', ' UK 6.4%', ' Sri Lanka 5.9%', ' Japan 4.6% (2015)']
# np
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/np.json
# ['India 61.3%', ' US 9.4% (2015)']
# pk
# https://raw.githubusercontent.com/factbook/factbook.json/master/south-asia/pk.json
# ['US 13.1%', ' UAE 9.1%', ' Afghanistan 9.1%', ' China 8.8%', ' UK 5.4%', ' Germany 4.9% (2015)']

# %%
for country in countries:
    print(countries[country].exporting_partners)
# Out:
# {'spain': 18.8, 'france': 11.2, 'us': 8.8, 'italy': 8.7, 'uk': 7.1, 'brazil': 5.2, 'tunisia': 4.9, 'germany': 4.5}
# {'china': 43.8, 'india': 9.6, 'us': 7.7, 'spain': 6.2, 'south africa': 4.8, 'france': 4.4}
# {'india': 24.2, 'gabon': 14.6, 'china': 7.2, 'niger': 6.0, 'bangladesh': 5.0, 'nigeria': 4.9, 'vietnam': 4.2}
# {'germany': 12.3, 'pakistan': 10.7, 'democratic republic of the congo': 10.7, 'uganda': 8.1, 'sweden': 7.8, 'us': 7.1, 'belgium': 6.3, 'rwanda': 4.6, 'france': 4.4}
# {'us': 58.5, 'india': 13.3, 'japan': 11.3, 'china': 4.1}
# {'china': 42.1, 'italy': 16.9, 'us': 4.9, 'india': 4.7, 'portugal': 4.2}
# {'china': 43.5, 'zambia': 25.0, 'south korea': 4.9, 'belgium': 4.8}
# {'china': 16.7, 'india': 15.7, 'spain': 6.2, 'belgium': 6.1, 'france': 6.1, 'portugal': 5.6, 'netherlands': 5.0, 'italy': 5.0}
# {'india': 28.7, 'france': 17.0, 'germany': 8.7, 'saudi arabia': 7.1, 'singapore': 6.6, 'netherlands': 6.1, 'mauritius': 5.3}
# {'norway': 52.2, 'china': 14.1, 'democratic republic of the congo': 8.3}
# {'australia': 83.0, 'spain': 8.6}
# {'somalia': 79.8, 'us': 5.4, 'yemen': 4.6, 'uae': 4.0}
# {'saudi arabia': 9.1, 'italy': 7.5, 'turkey': 5.8, 'uae': 5.1, 'us': 5.1, 'uk': 4.4, 'india': 4.1}
# {'china': 16.6, 'south korea': 15.1, 'spain': 9.0, 'brazil': 8.2, 'netherlands': 6.8, 'south africa': 6.6, 'india': 5.8, 'uk': 5.7, 'france': 5.7}
# {'switzerland': 14.3, 'china': 11.7, 'us': 9.5, 'netherlands': 8.8, 'saudi arabia': 5.9, 'germany': 5.7}
# {'china': 47.6, 'india': 27.2, 'france': 5.9, 'uk': 4.9}
# {'china': 15.5, 'italy': 7.3, 'trinidad and tobago': 7.2, 'australia': 7.0, 'spain': 6.3, 'south korea': 5.4, 'netherlands': 5.0, 'us': 4.7}
# {'india': 25.2, 'switzerland': 12.2, 'china': 10.6, 'france': 5.7}
# {'india': 22.5, 'spain': 8.2, 'ireland': 7.3, 'germany': 6.2, 'belgium': 5.5, 'ukraine': 5.3, 'france': 4.1}
# {'us': 8.5, 'netherlands': 6.2, 'france': 5.6, 'germany': 5.6, 'nigeria': 5.5, 'burkina faso': 5.5, 'belgium': 5.3, 'india': 4.6, 'ghana': 4.4, 'switzerland': 4.1}
# {'uganda': 11.2, 'us': 8.3, 'tanzania': 8.1, 'netherlands': 7.4, 'uk': 6.0, 'pakistan': 4.2}
# {'poland': 32.9, 'china': 20.7, 'india': 9.3, 'us': 5.1, 'greece': 4.7, 'france': 4.3}
# {'italy': 32.1, 'germany': 11.3, 'china': 8.0, 'france': 8.0, 'spain': 5.6, 'netherlands': 5.4, 'syria': 5.3}
# {'france': 15.2, 'us': 12.7, 'china': 7.1, 'south africa': 5.9, 'japan': 5.5, 'netherlands': 5.4, 'germany': 5.1, 'belgium': 5.0, 'india': 4.4}
# {'belgium': 15.8, 'zimbabwe': 12.0, 'india': 6.9, 'south africa': 6.2, 'us': 6.0, 'russia': 5.6, 'germany': 4.6}
# {'switzerland': 48.5, 'china': 9.4, 'india': 9.1, 'bangladesh': 8.0, 'thailand': 4.5, 'indonesia': 4.4}
# {'spain': 22.1, 'france': 19.7, 'india': 4.9, 'us': 4.3, 'italy': 4.3}
# {'uk': 13.2, 'uae': 12.4, 'france': 11.9, 'us': 10.7, 'south africa': 8.6, 'madagascar': 6.5, 'italy': 5.4, 'spain': 4.4}
# {'china': 32.7, 'switzerland': 11.1, 'spain': 8.6, 'italy': 6.7, 'cote divoire': 6.6, 'japan': 5.7}
# {'south africa': 24.9, 'china': 10.2, 'italy': 8.9, 'india': 8.9, 'belgium': 7.9, 'spain': 4.4}
# {'france': 53.1, 'nigeria': 20.3, 'china': 13.8}
# {'india': 18.2, 'netherlands': 8.5, 'spain': 8.2, 'brazil': 8.2, 'south africa': 7.8, 'france': 5.2, 'japan': 4.5, 'cote divoire': 4.2, 'ghana': 4.0}
# {'india': 63.5, 'nigeria': 20.3, 'china': 5.7, 'togo': 5.6}
# {'democratic republic of the congo': 19.8, 'us': 10.8, 'china': 10.3, 'swaziland': 7.9, 'malaysia': 7.0, 'pakistan': 6.2, 'germany': 5.9, 'thailand': 5.5}
# {'france': 18.2, 'uk': 17.9, 'mauritius': 10.0, 'japan': 9.2, 'italy': 7.8, 'spain': 4.5}
# {'china': 11.3, 'us': 7.3, 'germany': 6.0, 'namibia': 5.2, 'botswana': 5.2, 'japan': 4.7, 'uk': 4.3, 'india': 4.2}
# {'mali': 12.8, 'switzerland': 9.7, 'india': 5.9, 'cote divoire': 5.3, 'china': 5.1, 'uae': 4.1, 'france': 4.1}
# {'china': 31.3, 'belgium': 27.8, 'romania': 11.3, 'us': 7.3, 'india': 4.0}
# {'uae': 45.8, 'yemen': 19.7, 'oman': 15.9}
# {'uae': 32.0, 'china': 16.2, 'saudi arabia': 15.5, 'australia': 4.7, 'india': 4.2}
# {'india': 14.6, 'burkina faso': 11.3, 'china': 11.3, 'benin': 9.6, 'ghana': 9.0, 'lebanon': 8.3, 'nigeria': 6.1, 'niger': 5.9}
# {'netherlands': 29.2, 'belgium': 22.4, 'spain': 15.5, 'us': 6.6, 'nigeria': 5.1}
# {'france': 28.5, 'italy': 17.2, 'germany': 10.9, 'libya': 6.1, 'spain': 4.2}
# {'india': 21.4, 'china': 8.1, 'japan': 5.1, 'kenya': 4.6, 'belgium': 4.3}
# {'rwanda': 10.7, 'uae': 9.9, 'democratic republic of the congo': 9.8, 'kenya': 9.7, 'italy': 5.8, 'netherlands': 4.8, 'germany': 4.7, 'china': 4.1}
# {'switzerland': 53.3, 'india': 14.5}
# {'china': 25.5, 'democratic republic of the congo': 13.0, 'south africa': 6.4, 'south korea': 4.9, 'india': 4.3}
# {'china': 27.8, 'democratic republic of the congo': 14.0, 'botswana': 12.5, 'south africa': 7.6}
# {'us': 100.0}
# {'china': 32.2, 'japan': 15.9, 'south korea': 7.1, 'us': 5.4, 'india': 4.2}
# {'china': 61.7, 'india': 5.9, 'italy': 5.9}
# {'us': 13.4, 'australia': 10.2, 'samoa': 6.7, 'tonga': 5.9}
# {'japan': 35.0, 'us': 24.0, 'hong kong': 17.0, 'france': 9.1, 'china': 4.2}
# {'china': 31.8, 'japan': 15.2, 'south korea': 10.7, 'australia': 8.1, 'france': 7.4, 'belgium': 5.1}
# {'germany': 25.0, 'belgium': 11.0, 'united kingdom': 8.0, 'france': 8.0, 'italy': 4.0, 'united states': 4.0}
# {'japan': 35.1, 'turkey': 10.5, 'thailand': 8.7, 'china': 8.2, 'venezuela': 5.9, 'uk': 5.6}
# {'china': 17.5, 'australia': 16.9, 'us': 11.8, 'japan': 6.0}
# {'japan': 16.0, 'us': 15.4, 'fiji': 12.8, 'nz': 12.5, 'south korea': 11.0, 'samoa': 10.7, 'australia': 7.5, 'american samoa': 6.8}
# {'american samoa': 57.1, 'australia': 17.2}
# {'colombia': 28.2, 'netherlands antilles': 18.1, 'us': 14.3, 'netherlands': 10.1, 'mexico': 6.5, 'venezuela': 6.3, 'panama': 4.1}
# {'trinidad and tobago': 22.5, 'us': 11.8, 'st. lucia': 9.2, 'st. vincent and the grenadines': 5.7, 'antigua and barbuda': 4.7, 'st. kitts and nevis': 4.4, 'guyana': 4.2}
# {'poland': 26.3, 'cote divoire': 20.9, 'us': 15.9, 'dominican republic': 14.3}
# {'uk': 30.8, 'us': 18.7, 'nigeria': 6.7, 'trinidad and tobago': 4.8, 'ireland': 4.2, 'jamaica': 4.2}
# {'us': 33.6, 'china': 6.2, 'mexico': 4.6, 'nicaragua': 4.3, 'netherlands': 4.2, 'guatemala': 4.0}
# {'canada': 17.7, 'venezuela': 13.8, 'china': 13.0, 'netherlands': 6.4, 'spain': 5.4, 'belize': 4.7}
# {'japan': 38.1, 'jamaica': 19.0, 'antigua and barbuda': 10.4, 'trinidad and tobago': 6.2, 'st. lucia': 4.8, 'st. kitts and nevis': 4.2}
# {'us': 42.5, 'haiti': 16.5, 'canada': 8.1, 'india': 4.8}
# {'us': 47.1, 'honduras': 13.9, 'guatemala': 13.6, 'nicaragua': 6.6, 'costa rica': 4.5}
# {'nigeria': 44.7, 'st. lucia': 10.8, 'antigua and barbuda': 7.3, 'st. kitts and nevis': 6.6, 'dominica': 6.6, 'us': 5.8}
# {'us': 34.9, 'el salvador': 8.4, 'honduras': 7.3, 'nicaragua': 5.0, 'canada': 4.6, 'mexico': 4.3, 'costa rica': 4.1}
# {'us': 85.3}
# {'us': 36.0, 'germany': 8.7, 'el salvador': 8.5, 'guatemala': 6.0, 'nicaragua': 5.6, 'netherlands': 4.1}
# {'us': 24.4, 'canada': 16.5, 'russia': 9.3, 'netherlands': 8.9, 'iceland': 7.2, 'uk': 6.5}
# {'us': 56.5, 'mexico': 10.7, 'venezuela': 5.4, 'el salvador': 4.3}
# {'us': 19.7, 'germany': 13.2, 'costa rica': 7.7, 'china': 5.9, 'netherlands': 4.1}
# {'us': 44.4, 'poland': 14.6, 'bangladesh': 10.1, 'azerbaijan': 4.3}
# {'dominican republic': 25.1, 'us': 15.9, 'suriname': 9.1, 'antigua and barbuda': 7.0, 'dominica': 6.8, 'trinidad and tobago': 6.3, 'barbados': 6.1, 'uk': 4.8, 'grenada': 4.6}
# {'us': 26.3, 'argentina': 12.0, 'brazil': 6.6, 'chile': 5.3, 'dominican republic': 5.2, 'barbados': 5.0}
# {'trinidad and tobago': 18.9, 'st. lucia': 14.8, 'barbados': 12.3, 'dominica': 9.7, 'grenada': 9.3, 'antigua and barbuda': 8.4, 'poland': 7.1, 'st. kitts and nevis': 4.1}
# {'switzerland': 26.0, 'uzbekistan': 22.6, 'kazakhstan': 20.8, 'uae': 4.9, 'turkey': 4.5, 'afghanistan': 4.5, 'russia': 4.2}
# {'china': 15.1, 'russia': 12.3, 'france': 9.2, 'germany': 7.9, 'italy': 6.7, 'greece': 4.1}
# {'netherlands': 11.9, 'china': 8.3, 'germany': 7.4, 'italy': 6.5, 'turkey': 5.6, 'belarus': 4.4, 'japan': 4.2}
# {'turkey': 19.7, 'kazakhstan': 17.6, 'switzerland': 13.7, 'iran': 8.7, 'afghanistan': 7.5, 'russia': 5.1, 'china': 4.9, 'italy': 4.8}
# {'china': 68.6, 'turkey': 4.9}
# {'switzerland': 25.8, 'china': 17.6, 'kazakhstan': 14.2, 'turkey': 9.9, 'russia': 8.4, 'bangladesh': 6.9}
# {'china': 37.7, 'thailand': 25.6, 'india': 7.7, 'japan': 6.2}
# {'japan': 35.9, 'south korea': 14.8, 'thailand': 10.8, 'india': 9.8, 'nz': 5.6, 'australia': 5.0}
# {'us': 23.1, 'uk': 8.8, 'germany': 8.2, 'japan': 7.4, 'canada': 6.7, 'china': 5.1, 'vietnam': 5.0, 'thailand': 4.9, 'netherlands': 4.1}
# {'us': 18.0, 'hong kong': 14.6, 'japan': 6.0, 'south korea': 4.5}
# {'china': 53.7, 'us': 9.5}
# {'japan': 12.0, 'us': 10.8, 'china': 10.0, 'singapore': 8.4, 'india': 7.8, 'south korea': 5.1, 'malaysia': 5.1}
# {'us': 20.2, 'china': 17.5, 'south korea': 7.1, 'hong kong': 5.6, 'thailand': 4.5}
# {'china': 75.8}
# {'china': 26.0, 'us': 13.3, 'hong kong': 5.8, 'vietnam': 5.3, 'japan': 4.9}
# {'thailand': 30.4, 'china': 27.0, 'vietnam': 17.6}
# {'hong kong': 63.4, 'china': 18.2}
# {'china': 84.0, 'switzerland': 9.0}
# {'singapore': 13.9, 'china': 13.0, 'japan': 9.5, 'us': 9.4, 'thailand': 5.7, 'hong kong': 4.7, 'india': 4.1}
# {'japan': 17.4, 'australia': 15.9, 'china': 12.1}
# {'japan': 21.1, 'us': 15.0, 'china': 10.9, 'hong kong': 10.6, 'singapore': 6.2, 'germany': 4.5, 'south korea': 4.3}
# {'china': 13.7, 'hong kong': 11.5, 'malaysia': 10.8, 'indonesia': 8.2, 'us': 6.9, 'japan': 4.4, 'south korea': 4.1}
# {'us': 11.2, 'china': 11.1, 'japan': 9.4, 'hong kong': 5.5, 'malaysia': 4.8, 'australia': 4.6, 'vietnam': 4.2, 'singapore': 4.1}
# {'china': 27.1, 'hong kong': 13.2, 'us': 10.3, 'japan': 6.4, 'singapore': 4.4}
# {'us': 21.2, 'china': 13.3, 'japan': 8.4, 'south korea': 5.5, 'germany': 4.1}
# {'italy': 43.4, 'kosovo': 9.8, 'us': 7.7, 'china': 6.2, 'greece': 5.3, 'spain': 4.8}
# {'germany': 29.4, 'us': 6.4, 'italy': 6.1, 'switzerland': 5.7, 'france': 4.4, 'slovakia': 4.2}
# {'germany': 16.9, 'france': 15.5, 'netherlands': 11.4, 'uk': 8.8, 'us': 6.0, 'italy': 5.0}
# {'slovenia': 16.5, 'italy': 15.9, 'germany': 12.1, 'croatia': 11.5, 'austria': 11.1, 'turkey': 5.2}
# {'russia': 39.0, 'uk': 11.2, 'ukraine': 9.5, 'netherlands': 4.3, 'germany': 4.1}
# {'germany': 12.5, 'italy': 9.2, 'turkey': 8.5, 'romania': 8.2, 'greece': 6.5, 'france': 4.2}
# {'greece': 10.9, 'ireland': 10.2, 'uk': 7.2, 'israel': 6.0}
# {'germany': 17.8, 'sweden': 11.6, 'us': 8.4, 'norway': 6.3, 'uk': 6.3, 'netherlands': 4.4, 'china': 4.2}
# {'us': 23.7, 'uk': 13.8, 'belgium': 13.2, 'germany': 6.6, 'switzerland': 5.5, 'netherlands': 4.4, 'france': 4.4}
# {'sweden': 18.8, 'finland': 16.0, 'latvia': 10.4, 'russia': 6.7, 'lithuania': 5.9, 'germany': 5.2, 'norway': 4.1}
# {'germany': 32.4, 'slovakia': 9.0, 'poland': 5.8, 'uk': 5.3, 'france': 5.1, 'austria': 4.1}
# {'germany': 13.9, 'sweden': 10.1, 'us': 7.0, 'netherlands': 6.6, 'russia': 5.9, 'uk': 5.2, 'china': 4.7}
# {'russia': 20.2, 'uk': 16.6, 'denmark': 16.3, 'nigeria': 11.6, 'china': 9.3, 'us': 7.2, 'netherlands': 5.6, 'norway': 4.0}
# {'germany': 15.9, 'spain': 7.3, 'us': 7.2, 'italy': 7.1, 'uk': 7.1, 'belgium': 6.8}
# {'us': 9.6, 'france': 8.6, 'uk': 7.5, 'netherlands': 6.6, 'china': 6.0, 'italy': 4.9, 'austria': 4.8, 'poland': 4.4, 'switzerland': 4.2}
# {'italy': 11.2, 'germany': 7.3, 'turkey': 6.6, 'cyprus': 5.9, 'bulgaria': 5.2, 'us': 4.8, 'uk': 4.2, 'egypt': 4.0}
# {'italy': 13.4, 'slovenia': 12.5, 'germany': 11.4, 'bosnia and herzegovina': 9.9, 'austria': 6.6, 'serbia': 4.9}
# {'germany': 28.0, 'romania': 5.4, 'slovakia': 5.1, 'austria': 5.0, 'italy': 4.8, 'france': 4.7, 'uk': 4.0, 'czech republic': 4.0}
# {'netherlands': 26.1, 'uk': 11.6, 'spain': 11.5, 'germany': 7.4, 'france': 5.7, 'us': 5.7, 'norway': 4.7}
# {'germany': 12.3, 'france': 10.3, 'us': 8.7, 'uk': 5.4, 'spain': 4.8, 'switzerland': 4.7}
# {'italy': 25.8, 'albania': 14.6, 'macedonia': 9.6, 'china': 5.5, 'germany': 5.4, 'switzerland': 5.4, 'turkey': 4.1}
# {'lithuania': 17.8, 'russia': 11.5, 'estonia': 11.1, 'germany': 6.3, 'poland': 5.6, 'sweden': 5.2, 'uk': 5.0, 'denmark': 4.0}
# {'russia': 13.7, 'latvia': 9.8, 'poland': 9.7, 'germany': 7.8, 'estonia': 5.3, 'belarus': 4.6, 'uk': 4.5, 'us': 4.4, 'netherlands': 4.0}
# {'germany': 22.7, 'czech republic': 12.5, 'poland': 8.5, 'austria': 5.7, 'hungary': 5.7, 'france': 5.6, 'uk': 5.5, 'italy': 4.5}
# {'germany': 22.1, 'belgium': 16.7, 'france': 16.6, 'uk': 4.7, 'italy': 4.6, 'netherlands': 4.0}
# {'romania': 23.1, 'italy': 10.2, 'turkey': 9.4, 'russia': 8.0, 'germany': 6.6, 'belarus': 6.4}
# {'croatia': 22.7, 'serbia': 22.7, 'slovenia': 7.8}
# {'germany': 33.2, 'kosovo': 11.5, 'bulgaria': 5.1, 'greece': 4.5}
# {'europe': 73.2, 'africa': 14.6, 'america': 5.2, 'asia': 4.9}
# {'germany': 13.3, 'france': 10.2, 'hong kong': 7.4, 'singapore': 7.3, 'uk': 6.4, 'us': 5.8, 'italy': 5.6, 'japan': 4.7}
# {'germany': 24.5, 'belgium': 11.1, 'uk': 9.3, 'france': 8.4, 'italy': 4.2}
# {'uk': 22.2, 'germany': 17.9, 'netherlands': 10.2, 'france': 6.6, 'sweden': 6.1, 'belgium': 5.0, 'us': 4.5}
# {'germany': 27.1, 'uk': 6.8, 'czech republic': 6.6, 'france': 5.5, 'italy': 4.8, 'netherlands': 4.4}
# {'spain': 25.0, 'france': 12.1, 'germany': 11.8, 'uk': 6.7, 'us': 5.2, 'angola': 4.2, 'netherlands': 4.0}
# {'italy': 16.2, 'germany': 12.6, 'bosnia and herzegovina': 8.7, 'romania': 5.6, 'russia': 5.4}
# {'germany': 19.8, 'italy': 12.5, 'france': 6.8, 'hungary': 5.4, 'uk': 4.4}
# {'germany': 19.1, 'italy': 10.6, 'austria': 8.0, 'croatia': 6.8, 'slovakia': 4.7, 'hungary': 4.4, 'france': 4.2}
# {'italy': 82.3}
# {'france': 15.7, 'germany': 11.0, 'italy': 7.4, 'uk': 7.4, 'portugal': 7.1, 'us': 4.5}
# {'norway': 10.3, 'germany': 10.3, 'us': 7.7, 'uk': 7.2, 'denmark': 6.8, 'finland': 6.7, 'netherlands': 5.2, 'belgium': 4.4, 'france': 4.2}
# {'germany': 14.2, 'us': 10.6, 'hong kong': 8.7, 'india': 7.3, 'china': 6.9, 'france': 6.1, 'italy': 5.4, 'uk': 4.8}
# {'us': 14.6, 'germany': 10.1, 'switzerland': 7.0, 'china': 6.0, 'france': 5.9, 'netherlands': 5.8, 'ireland': 5.5}
# {'russia': 12.7, 'turkey': 7.3, 'china': 6.3, 'egypt': 5.5, 'italy': 5.2, 'poland': 5.2}
# {'iran': 14.5, 'japan': 9.8, 'india': 9.2, 'china': 4.7, 'oman': 4.3}
# {'italy': 26.3, 'germany': 13.3, 'indonesia': 7.0, 'france': 6.9, 'czech republic': 6.0}
# {'russia': 15.2, 'china': 11.1, 'germany': 9.8, 'iraq': 8.8, 'georgia': 7.8, 'canada': 7.6, 'bulgaria': 5.3, 'iran': 5.3}
# {'saudi arabia': 3.6, 'uae': 2.4, 'us': 2.2}
# {'azerbaijan': 10.9, 'bulgaria': 9.7, 'turkey': 8.4, 'armenia': 8.2, 'russia': 7.4, 'china': 5.7, 'us': 4.7, 'uzbekistan': 4.4}
# {'china': 22.2, 'india': 9.9, 'turkey': 8.4, 'japan': 4.5}
# {'us': 27.5, 'hong kong': 8.0, 'uk': 6.1, 'china': 4.9}
# {'china': 22.6, 'india': 21.1, 'south korea': 11.2, 'us': 7.8, 'italy': 6.7, 'greece': 6.0}
# {'us': 21.0, 'saudi arabia': 16.5, 'iraq': 10.3, 'india': 8.7, 'uae': 4.8, 'kuwait': 4.4}
# {'south korea': 14.5, 'china': 12.1, 'india': 12.1, 'japan': 10.4, 'us': 7.6, 'pakistan': 5.9, 'singapore': 4.3}
# {'saudi arabia': 12.1, 'uae': 10.6, 'iraq': 7.6, 'syria': 7.1, 'south africa': 6.6}
# {'china': 35.4, 'uae': 15.3, 'south korea': 6.8, 'saudi arabia': 5.8, 'pakistan': 4.2}
# {'japan': 25.4, 'india': 14.6, 'china': 8.4, 'uae': 6.8, 'singapore': 5.6, 'uk': 5.5, 'thailand': 4.2}
# {'china': 13.2, 'japan': 10.9, 'us': 9.6, 'india': 9.6, 'south korea': 8.5}
# {'iraq': 64.7, 'saudi arabia': 11.2, 'kuwait': 7.1, 'uae': 6.1, 'libya': 4.6}
# {'germany': 9.3, 'uk': 7.3, 'iraq': 5.9, 'italy': 4.8, 'us': 4.5, 'france': 4.1}
# {'china': 24.5, 'uae': 16.5, 'south korea': 10.0, 'saudi arabia': 10.0, 'kuwait': 9.1, 'india': 8.5}
# {'us': 14.4, 'iceland': 13.7, 'spain': 6.8, 'uk': 5.8, 'mauritius': 5.6}
# {'us': 76.7}
# {'denmark': 51.6, 'china': 11.1, 'japan': 9.1, 'russia': 7.2}
# {'us': 81.1}
# {'canada': 18.6, 'mexico': 15.7, 'china': 7.7, 'japan': 4.2}
# {'brazil': 17.0, 'china': 8.6, 'us': 5.9}
# {'brazil': 28.1, 'argentina': 16.9, 'us': 12.1, 'colombia': 6.3, 'china': 5.3, 'japan': 4.7, 'south korea': 4.3}
# {'china': 18.6, 'us': 12.7, 'argentina': 6.7, 'netherlands': 5.3}
# {'china': 26.3, 'us': 13.2, 'japan': 8.5, 'south korea': 6.5, 'brazil': 4.9}
# {'us': 27.5, 'panama': 7.2, 'china': 5.2, 'spain': 4.4, 'ecuador': 4.0}
# {'us': 39.5, 'chile': 6.2, 'peru': 5.1, 'vietnam': 4.3, 'colombia': 4.3}
# {'us': 33.5, 'canada': 17.9, 'uk': 6.7, 'ukraine': 4.3, 'jamaica': 4.0}
# {'switzerland': 21.8, 'uae': 14.5, 'india': 13.9, 'belgium': 9.7, 'us': 8.9, 'france': 8.1, 'canada': 6.6}
# {'brazil': 31.7, 'russia': 9.1, 'chile': 7.1, 'argentina': 7.0}
# {'china': 22.1, 'us': 15.2, 'switzerland': 8.1, 'canada': 7.0}
# {'china': 15.0, 'brazil': 14.4, 'us': 6.5, 'argentina': 4.9}
# {'us': 26.6, 'india': 13.7, 'china': 11.7, 'cuba': 6.4}
# {'india': 42.3, 'pakistan': 29.0, 'tajikistan': 7.6}
# {'us': 13.9, 'germany': 12.9, 'uk': 8.9, 'france': 5.0, 'spain': 4.7}
# {'india': 83.8, 'hong kong': 10.8}
# {'us': 26.0, 'uk': 9.0, 'india': 7.2, 'germany': 4.3}
# {'us': 15.2, 'uae': 11.4, 'hong kong': 4.6}
# {'thailand': 18.0, 'france': 12.1, 'germany': 10.7, 'us': 9.6, 'italy': 6.8, 'uk': 6.4, 'sri lanka': 5.9, 'japan': 4.6}
# {'india': 61.3, 'us': 9.4}
# {'us': 13.1, 'uae': 9.1, 'afghanistan': 9.1, 'china': 8.8, 'uk': 5.4, 'germany': 4.9}

# %%
import pandas as pd
import networkx as nx
import matplotlib as plt
G = nx.Graph()

for country in countries:
    for partner in countries[country].exporting_partners: 
        G.add_edge(countries[country].name, partner, weight=countries[country].exporting_partners[partner]/100)

# %%
from networkx.readwrite import json_graph
data = json_graph.node_link_data(G)

# %%
import json
with open('graph.json', 'w') as fp:
    json.dump(data, fp)
